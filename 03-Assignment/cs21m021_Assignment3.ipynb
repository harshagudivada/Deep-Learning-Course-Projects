# %%
# !pip install wandb
# !pip install wordcloud
# !pip install colour
# Out:
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 11.3 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 11.0 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 52.4 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=bc8d9ce6313b3b7853c9ab6acead55bcf303adda21c795bb4f2f38fc5f3b4873
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour
# Successfully installed colour-0.1.5

# %%
## Installing font for Hindi for matplotlib ##
# !apt-get install -y fonts-lohit-deva
# !fc-list :lang=hi family
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   fonts-lohit-deva
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 78.2 kB of archives.
# After this operation, 196 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lohit-deva all 2.95.4-2 [78.2 kB]
# Fetched 78.2 kB in 1s (84.3 kB/s)
# Selecting previously unselected package fonts-lohit-deva.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../fonts-lohit-deva_2.95.4-2_all.deb ...
# Unpacking fonts-lohit-deva (2.95.4-2) ...
# Setting up fonts-lohit-deva (2.95.4-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Lohit Devanagari

# %%
import os
import random
import time
import wandb
import re, string
import numpy as np
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from colour import Color
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Data Loading

# %%
## Download the dataset ##
import requests
import tarfile

def download_data(save_path):

    data_url = r"https://storage.googleapis.com/gresearch/dakshina/dakshina_dataset_v1.0.tar"

    r = requests.get(data_url, allow_redirects=True)
    tar_path = "data_assignment3.tar"

    if r.status_code == 200:
        with open(tar_path, 'wb') as f:
            f.write(r.content)

    tar_file = tarfile.open(tar_path)
    tar_file.extractall(save_path)
    tar_file.close()



# uncomment the line below if downloading data for the 1st time
# download_data("/content/drive/MyDrive/DakshinaDataset")

# %% [markdown]
# #Prepocessing the Data

# %%
def get_data_files(language):
    """ Function fo read data 
    """

    template = "/content/drive/MyDrive/DakshinaDataset/dakshina_dataset_v1.0/{}/lexicons/{}.translit.sampled.{}.tsv"

    train_tsv = template.format(language, language, "train")
    val_tsv = template.format(language, language, "dev")
    test_tsv = template.format(language, language, "test")

    return train_tsv, val_tsv, test_tsv


def add_start_end_tokens(df, cols, sos="\t", eos="\n"):
    """ Adds EOS and SOS tokens to data 
    """
    def add_tokens(s):  
        # \t = starting token
        # \n = ending token
        return sos + str(s) + eos

    for col in cols:
        df[col] = df[col].apply(add_tokens) 
    
def tokenize(lang, tokenizer=None):
    """ Uses tf.keras tokenizer to tokenize the data/words into characters
    """

    if tokenizer is None:
        tokenizer = Tokenizer(char_level=True)
        tokenizer.fit_on_texts(lang)

        lang_tensor = tokenizer.texts_to_sequences(lang)
        lang_tensor = tf.keras.preprocessing.sequence.pad_sequences(lang_tensor,
                                                            padding='post')

    else: 
        lang_tensor = tokenizer.texts_to_sequences(lang)
        lang_tensor = tf.keras.preprocessing.sequence.pad_sequences(lang_tensor,
                                                            padding='post')

    return lang_tensor, tokenizer

def preprocess_data(fpath, input_lang_tokenizer=None, targ_lang_tokenizer=None):
    """ Reads, tokenizes and adds SOS/EOS tokens to data based on above functions
    """

    df = pd.read_csv(fpath, sep="\t", header=None)

    # Addition of start and end tokens
    add_start_end_tokens(df, [0,1])
    
    input_lang_tensor, input_tokenizer = tokenize(df[1].astype(str).tolist(), 
                                                    tokenizer=input_lang_tokenizer)
    
    targ_lang_tensor, targ_tokenizer = tokenize(df[0].astype(str).tolist(),
                                                    tokenizer=targ_lang_tokenizer) 
    
    dataset = tf.data.Dataset.from_tensor_slices((input_lang_tensor, targ_lang_tensor))
    dataset = dataset.shuffle(len(dataset))
    
    return dataset, input_tokenizer, targ_tokenizer

# %% [markdown]
# #Building the Model

# %%
def get_layer(name, units, dropout, return_state=False, return_sequences=False):

    if name=="rnn":
        return layers.SimpleRNN(units=units, dropout=dropout, 
                                return_state=return_state,
                                return_sequences=return_sequences)

    if name=="gru":
        return layers.GRU(units=units, dropout=dropout, 
                          return_state=return_state,
                          return_sequences=return_sequences)

    if name=="lstm":
        return layers.LSTM(units=units, dropout=dropout, 
                           return_state=return_state,
                           return_sequences=return_sequences)

#Attention
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, enc_state, enc_out):
    
    enc_state = tf.concat(enc_state, 1)
    enc_state = tf.expand_dims(enc_state, 1)

    score = self.V(tf.nn.tanh(self.W1(enc_state) + self.W2(enc_out)))

    attention_weights = tf.nn.softmax(score, axis=1)

    context_vector = attention_weights * enc_out
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights


class Encoder(tf.keras.Model):
    def __init__(self, layer_type, n_layers, units, encoder_vocab_size, embedding_dim, dropout):
        super(Encoder, self).__init__()
        self.layer_type = layer_type
        self.n_layers = n_layers
        self.units = units
        self.dropout = dropout
        self.embedding = tf.keras.layers.Embedding(encoder_vocab_size, embedding_dim)
        self.create_rnn_layers()

    def call(self, x, hidden):
        x = self.embedding(x)
        x = self.rnn_layers[0](x, initial_state=hidden)

        for layer in self.rnn_layers[1:]:
            x = layer(x)

        output, state = x[0], x[1:]

        return output, state
    
    def create_rnn_layers(self):
        self.rnn_layers = []

        for i in range(self.n_layers):
            self.rnn_layers.append(get_layer(self.layer_type, self.units, self.dropout,
                                                return_sequences=True,
                                                return_state=True))


    def initialize_hidden_state(self, batch_size):

        if self.layer_type != "lstm":
            return [tf.zeros((batch_size, self.units))]
        else:
            return [tf.zeros((batch_size, self.units))]*2

class Decoder(tf.keras.Model):
    def __init__(self, layer_type, n_layers, units, decoder_vocab_size, embedding_dim, dropout, attention=False):
        super(Decoder, self).__init__()

        self.layer_type = layer_type
        self.n_layers = n_layers
        self.units = units
        self.dropout = dropout
        self.attention = attention
        self.embedding_layer = layers.Embedding(input_dim=decoder_vocab_size, 
                                                output_dim=embedding_dim)
        
        self.dense = layers.Dense(decoder_vocab_size, activation="softmax")
        self.flatten = layers.Flatten()
        if self.attention:
            self.attention_layer = BahdanauAttention(self.units)
        self.create_rnn_layers()

    def call(self, x, hidden, enc_out=None):
        
        x = self.embedding_layer(x)

        if self.attention:
            context_vector, attention_weights = self.attention_layer(hidden, enc_out)
            x = tf.concat([tf.expand_dims(context_vector, 1), x], -1)
        else:
            attention_weights = None

        x = self.rnn_layers[0](x, initial_state=hidden)

        for layer in self.rnn_layers[1:]:
            x = layer(x)

        output, state = x[0], x[1:]

        output = self.dense(self.flatten(output))
        
        return output, state, attention_weights

    def create_rnn_layers(self):
        self.rnn_layers = []    

        for i in range(self.n_layers - 1):
            self.rnn_layers.append(get_layer(self.layer_type, self.units, self.dropout,
                                                return_sequences=True,
                                                return_state=True))
        
        self.rnn_layers.append(get_layer(self.layer_type, self.units, self.dropout,
                                            return_sequences=False,
                                            return_state=True))

# %% [markdown]
# #Core Sequence to Sequence Model

# %%
class Seq2SeqModel():
    def __init__(self, embedding_dim, encoder_layers, decoder_layers, layer_type, units, dropout, attention=False):
        self.embedding_dim = embedding_dim
        self.encoder_layers = encoder_layers
        self.decoder_layers = decoder_layers
        self.layer_type = layer_type
        self.units = units
        self.dropout = dropout
        self.attention = attention
        self.stats = []
        self.batch_size = 128

    def build(self, loss, optimizer, metric):
        self.loss = loss
        self.optimizer = optimizer
        self.metric = metric

    def set_vocabulary(self, input_tokenizer, targ_tokenizer):
        self.input_tokenizer = input_tokenizer
        self.targ_tokenizer = targ_tokenizer
        self.create_model()
    
    def create_model(self):

        encoder_vocab_size = len(self.input_tokenizer.word_index) + 1
        decoder_vocab_size = len(self.targ_tokenizer.word_index) + 1

        self.encoder = Encoder(self.layer_type, self.encoder_layers, self.units, encoder_vocab_size,
                               self.embedding_dim, self.dropout)

        self.decoder = Decoder(self.layer_type, self.decoder_layers, self.units, decoder_vocab_size,
                               self.embedding_dim,  self.dropout, self.attention)

    @tf.function
    def train_step(self, input, target, enc_state):

        loss = 0 

        with tf.GradientTape() as tape: 

            enc_out, enc_state = self.encoder(input, enc_state)

            dec_state = enc_state
            dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*self.batch_size ,1)

            #Teacher Forcing

            if random.random() < self.teacher_forcing_ratio:

                for t in range(1, target.shape[1]):

                    preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
                    loss += self.loss(target[:,t], preds)
                    self.metric.update_state(target[:,t], preds)
                    
                    dec_input = tf.expand_dims(target[:,t], 1)
            
            else:

                for t in range(1, target.shape[1]):

                    preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
                    loss += self.loss(target[:,t], preds)
                    self.metric.update_state(target[:,t], preds)

                    preds = tf.argmax(preds, 1)
                    dec_input = tf.expand_dims(preds, 1)


            batch_loss = loss / target.shape[1]

            variables = self.encoder.variables + self.decoder.variables
            gradients = tape.gradient(loss, variables)

            self.optimizer.apply_gradients(zip(gradients, variables))

        return batch_loss, self.metric.result()

    @tf.function
    def validation_step(self, input, target, enc_state):

        loss = 0
        
        enc_out, enc_state = self.encoder(input, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*self.batch_size ,1)

        for t in range(1, target.shape[1]):

            preds, dec_state, _ = self.decoder(dec_input, dec_state, enc_out)
            loss += self.loss(target[:,t], preds)
            self.metric.update_state(target[:,t], preds)

            preds = tf.argmax(preds, 1)
            dec_input = tf.expand_dims(preds, 1)

        batch_loss = loss / target.shape[1]
        
        return batch_loss, self.metric.result()


    def fit(self, dataset, val_dataset, batch_size=128, epochs=10, use_wandb=False, teacher_forcing_ratio=1.0):

        self.batch_size = batch_size
        self.teacher_forcing_ratio = teacher_forcing_ratio

        steps_per_epoch = len(dataset) // self.batch_size
        steps_per_epoch_val = len(val_dataset) // self.batch_size
        
        dataset = dataset.batch(self.batch_size, drop_remainder=True)
        val_dataset = val_dataset.batch(self.batch_size, drop_remainder=True)

        #Translation
        sample_inp, sample_targ = next(iter(dataset))
        self.max_target_len = sample_targ.shape[1]
        self.max_input_len = sample_inp.shape[1]

        template = "\nTrain Loss: {0:.4f} Train Accuracy: {1:.4f} Validation Loss: {2:.4f} Validation Accuracy: {3:.4f}"

        print("-"*100)
        for epoch in range(1, epochs+1):
            print(f"EPOCH {epoch}\n")

            
            total_loss = 0
            total_acc = 0
            self.metric.reset_states()

            starting_time = time.time()
            enc_state = self.encoder.initialize_hidden_state(self.batch_size)

            print("Training ...\n")
            for batch, (input, target) in enumerate(dataset.take(steps_per_epoch)):
                batch_loss, acc = self.train_step(input, target, enc_state)
                total_loss += batch_loss
                total_acc += acc


                if batch==0 or ((batch + 1) % 100 == 0):
                    print(f"Batch {batch+1} Loss {batch_loss:.4f}")

            avg_acc = total_acc / steps_per_epoch
            avg_loss = total_loss / steps_per_epoch

            # Validation
            total_val_loss = 0
            total_val_acc = 0
            self.metric.reset_states()

            enc_state = self.encoder.initialize_hidden_state(self.batch_size)

            print("\nValidating ...")
            for batch, (input, target) in enumerate(val_dataset.take(steps_per_epoch_val)):
                batch_loss, acc = self.validation_step(input, target, enc_state)
                total_val_loss += batch_loss
                total_val_acc += acc

            avg_val_acc = total_val_acc / steps_per_epoch_val
            avg_val_loss = total_val_loss / steps_per_epoch_val

            print(template.format(avg_loss, avg_acc*100, avg_val_loss, avg_val_acc*100))
            
            time_taken = time.time() - starting_time
            self.stats.append({"epoch": epoch,
                            "train loss": avg_loss,
                            "val loss": avg_val_loss,
                            "train acc": avg_acc*100,
                            "val acc": avg_val_acc*100,
                            "training time": time_taken})
            
            if use_wandb:
                wandb.log(self.stats[-1])
            
            print(f"\nTime taken for the epoch {time_taken:.4f}")
            print("-"*100)
        
        print("\nModel trained successfully !!")
        
    def evaluate(self, test_dataset, batch_size=None):

        if batch_size is not None:
            self.batch_size = batch_size

        steps_per_epoch_test = len(test_dataset) // batch_size
        test_dataset = test_dataset.batch(batch_size, drop_remainder=True)
        
        total_test_loss = 0
        total_test_acc = 0
        self.metric.reset_states()

        enc_state = self.encoder.initialize_hidden_state(self.batch_size)

        print("\nRunning test dataset through the model...\n")
        for batch, (input, target) in enumerate(test_dataset.take(steps_per_epoch_test)):
            batch_loss, acc = self.validation_step(input, target, enc_state)
            total_test_loss += batch_loss
            total_test_acc += acc

        avg_test_acc = total_test_acc / steps_per_epoch_test
        avg_test_loss = total_test_loss / steps_per_epoch_test
    
        print(f"Test Loss: {avg_test_loss:.4f} Test Accuracy: {avg_test_acc:.4f}")

        return avg_test_loss, avg_test_acc


    def translate(self, word, get_heatmap=False):

        word = "\t" + word + "\n"

        inputs = self.input_tokenizer.texts_to_sequences([word])
        inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                               maxlen=self.max_input_len,
                                                               padding="post")

        result = ""
        att_wts = []

        enc_state = self.encoder.initialize_hidden_state(1)
        enc_out, enc_state = self.encoder(inputs, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([self.targ_tokenizer.word_index["\t"]]*1, 1)

        for t in range(1, self.max_target_len):

            preds, dec_state, attention_weights = self.decoder(dec_input, dec_state, enc_out)
            
            if get_heatmap:
                att_wts.append(attention_weights)
            
            preds = tf.argmax(preds, 1)
            next_char = self.targ_tokenizer.index_word[preds.numpy().item()]
            result += next_char

            dec_input = tf.expand_dims(preds, 1)

            if next_char == "\n":
                return result[:-1], att_wts[:-1]

        return result[:-1], att_wts[:-1]

# %%
def randomly_evaluate(model, test_file=get_data_files("hi")[2], n=10):

    df = pd.read_csv(test_file, sep="\t", header=None)
    df = df.sample(n=n).reset_index(drop=True)

    print(f"Randomly evaluating the model on {n} words\n")

    for i in range(n):
        word = str(df[1][i])

        print(f"Input word: {word}")
        print(f"Actual translation: {str(df[0][i])}")
        print(f"Model translation: {model.translate(word)[0]}\n")


def test_on_dataset(language, embedding_dim, encoder_layers, decoder_layers, layer_type, units, dropout, attention, teacher_forcing_ratio=1.0, save_outputs=None):
    
    TRAIN_TSV, VAL_TSV, TEST_TSV = get_data_files(language)

    model = Seq2SeqModel(embedding_dim, 
                         encoder_layers, 
                         decoder_layers, 
                         layer_type, 
                         units,
                         dropout,
                         attention)

    dataset, input_tokenizer, targ_tokenizer = preprocess_data(TRAIN_TSV)
    val_dataset, _, _ = preprocess_data(VAL_TSV, input_tokenizer, targ_tokenizer)

    model.set_vocabulary(input_tokenizer, targ_tokenizer)
    model.build(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metric = tf.keras.metrics.SparseCategoricalAccuracy())
    
    model.fit(dataset, val_dataset, epochs=20, use_wandb=False, teacher_forcing_ratio=teacher_forcing_ratio)


    test_dataset, _, _ = preprocess_data(TEST_TSV, model.input_tokenizer, model.targ_tokenizer)
    test_loss, test_acc = model.evaluate(test_dataset, batch_size=100)

    ##  Wordaccuracy
    test_tsv = pd.read_csv(TEST_TSV, sep="\t", header=None)
    inputs = test_tsv[1].astype(str).tolist()
    targets = test_tsv[0].astype(str).tolist()
    
    outputs = []

    for word in inputs:
        outputs.append(model.translate(word)[0])

    def word_level_acc(outputs, targets):
        return np.sum(np.asarray(outputs) == np.array(targets)) / len(outputs)

    print(f"Word level accuracy: {word_level_acc(outputs, targets)}")

    if save_outputs is not None:
        df = pd.DataFrame()
        df["inputs"] = inputs
        df["targets"] = targets
        df["outputs"] = outputs
        df.to_csv(save_outputs)


    return model

# %% [markdown]
# #Model Connectivity Visualization

# %%
def get_lstm_output(decoder, x, hidden, enc_out=None):
    
    x = decoder.embedding_layer(x)

    if decoder.attention:
        context_vector, attention_weights = decoder.attention_layer(hidden, enc_out)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], -1)
    else:
        attention_weights = None

    x = decoder.rnn_layers[0](x, initial_state=hidden)

    for layer in decoder.rnn_layers[1:]:
        x = layer(x)

    output, state = x[0], x[1:]

    
    return output, state, attention_weights

def get_output_from_embedding(encoder, x, hidden):

    x = encoder.rnn_layers[0](x, initial_state=hidden)

    for layer in encoder.rnn_layers[1:]:
        x = layer(x)

    output, state = x[0], x[1:]

    return output, state


def get_connectivity(model, word):

    word = "\t" + word + "\n"

    inputs = model.input_tokenizer.texts_to_sequences([word])
    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                            maxlen=model.max_input_len,
                                                            padding="post")

    result = ""

    gradient_list = []

    enc_state = model.encoder.initialize_hidden_state(1)
    embedded_in = model.encoder.embedding(inputs)


    with tf.GradientTape(persistent=True, watch_accessed_variables=False) as tape:
        tape.watch(embedded_in)

        enc_out, enc_state = get_output_from_embedding(model.encoder, embedded_in, enc_state)

        dec_state = enc_state
        dec_input = tf.expand_dims([model.targ_tokenizer.word_index["\t"]]*1, 1)

        for t in range(1, model.max_target_len):

            lstm_out, dec_state, _ = get_lstm_output(model.decoder, dec_input, dec_state, enc_out)

            preds = model.decoder.dense(model.decoder.flatten(lstm_out))
            gradient_list.append(tape.gradient(lstm_out, embedded_in)[0])
            
            preds = tf.argmax(preds, 1)
            next_char = model.targ_tokenizer.index_word[preds.numpy().item()]
            result += next_char

            dec_input = tf.expand_dims(preds, 1)

            if next_char == "\n":
                return result[:-1], gradient_list[:-1]

        return result[:-1], gradient_list[:-1]

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from IPython.display import HTML as html_print
from IPython.display import display
import tensorflow.keras.backend as K

#html 
def cstr(s, color='black'):
    if s == ' ':
      return "<text style=color:#000;padding-left:10px;background-color:{}> </text>".format(color, s)
    else:
      return "<text style=color:#000;background-color:{}>{} </text>".format(color, s)
	
# print html
def print_color(t):
	  display(html_print(''.join([cstr(ti, color=ci) for ti,ci in t])))

# get color
def get_clr(value):
    colors = ['#85c2e1', '#89c4e2', '#95cae5', '#99cce6', '#a1d0e8'
      '#b2d9ec', '#baddee', '#c2e1f0', '#eff7fb', '#f9e8e8',
      '#f9e8e8', '#f9d4d4', '#f9bdbd', '#f8a8a8', '#f68f8f',
      '#f47676', '#f45f5f', '#f34343', '#f33b3b', '#f42e2e']
    value = int(value * 19)
    if value == 19:
        value -= 1
    return colors[value]

def sigmoid(x):
    z = 1/(1 + np.exp(-x)) 
    return z

def softmax(x):
    v = np.exp(x)
    v = v / np.sum(v)
    return v

def get_gradient_norms(grad_list, word, activation="sigmoid"):
    grad_norms = []
    for grad_tensor in grad_list:
        grad_mags = tf.norm(grad_tensor, axis=1)
        grad_mags = grad_mags[:len(word)]
        if activation == "softmax":
            grad_mags_scaled = softmax(grad_mags)
        elif activation == "scaler":
            scaler = MinMaxScaler()
            grad_mags = tf.reshape(grad_mags, (-1,1))
            grad_mags_scaled = scaler.fit_transform(grad_mags)
        else:
            grad_mags_scaled = sigmoid(grad_mags)
        grad_norms.append(grad_mags_scaled)
    return grad_norms

def visualize(grad_norms, word, translated_word):
    print("Original Word:", word)
    print("Transliterated Word:", translated_word)
    for i in range(len(translated_word)):
        print("Connectivity Visualization for", translated_word[i],":")
        text_colours = []
        for j in range(len(grad_norms[i])):
            text = (word[j], get_clr(grad_norms[i][j]))
            text_colours.append(text)
        print_color(text_colours)

def visualise_connectivity(model, word, activation="sigmoid"):
    translated_word, grad_list = get_connectivity(model, word)
    grad_norms = get_gradient_norms(grad_list, word, activation)
    visualize(grad_norms, word, translated_word)

# %% [markdown]
# #Testing without attention

# %%
#Testing on the dataset with the best hyper parameters found after sweeps.
model = test_on_dataset(language="hi",
                        embedding_dim=256,
                        encoder_layers=3,
                        decoder_layers=3,
                        layer_type="lstm",
                        units=256,
                        dropout=0.2,
                        attention=False, save_outputs='predictions_vanilla.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9883
# Batch 100 Loss 1.0728
# Batch 200 Loss 0.9839
# Batch 300 Loss 0.9155
#
# Validating ...
#
# Train Loss: 1.1216 Train Accuracy: 66.9055 Validation Loss: 2.8826 Validation Accuracy: 44.6775
#
# Time taken for the epoch 120.6969
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.8923
# Batch 100 Loss 0.8731
# Batch 200 Loss 0.7926
# Batch 300 Loss 0.7589
#
# Validating ...
#
# Train Loss: 0.8292 Train Accuracy: 74.8300 Validation Loss: 3.2128 Validation Accuracy: 45.6532
#
# Time taken for the epoch 33.6026
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.7498
# Batch 100 Loss 0.6860
# Batch 200 Loss 0.5596
# Batch 300 Loss 0.5896
#
# Validating ...
#
# Train Loss: 0.6396 Train Accuracy: 79.4184 Validation Loss: 2.8029 Validation Accuracy: 53.8147
#
# Time taken for the epoch 33.4504
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.5601
# Batch 100 Loss 0.5115
# Batch 200 Loss 0.4587
# Batch 300 Loss 0.4281
#
# Validating ...
#
# Train Loss: 0.4858 Train Accuracy: 83.7704 Validation Loss: 2.5060 Validation Accuracy: 59.0801
#
# Time taken for the epoch 33.8639
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.4196
# Batch 100 Loss 0.3763
# Batch 200 Loss 0.3423
# Batch 300 Loss 0.3524
#
# Validating ...
#
# Train Loss: 0.3596 Train Accuracy: 87.5505 Validation Loss: 2.3092 Validation Accuracy: 63.1314
#
# Time taken for the epoch 33.6990
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.2925
# Batch 100 Loss 0.2612
# Batch 200 Loss 0.2693
# Batch 300 Loss 0.2409
#
# Validating ...
#
# Train Loss: 0.2638 Train Accuracy: 90.9744 Validation Loss: 1.9603 Validation Accuracy: 70.0115
#
# Time taken for the epoch 33.3075
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.1996
# Batch 100 Loss 0.2302
# Batch 200 Loss 0.1613
# Batch 300 Loss 0.1733
#
# Validating ...
#
# Train Loss: 0.2056 Train Accuracy: 93.0386 Validation Loss: 1.8038 Validation Accuracy: 72.8147
#
# Time taken for the epoch 33.2689
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.1660
# Batch 100 Loss 0.1826
# Batch 200 Loss 0.1611
# Batch 300 Loss 0.1791
#
# Validating ...
#
# Train Loss: 0.1680 Train Accuracy: 94.3875 Validation Loss: 1.4984 Validation Accuracy: 78.4322
#
# Time taken for the epoch 33.6929
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.1488
# Batch 100 Loss 0.1758
# Batch 200 Loss 0.1345
# Batch 300 Loss 0.1552
#
# Validating ...
#
# Train Loss: 0.1404 Train Accuracy: 95.3042 Validation Loss: 1.6145 Validation Accuracy: 77.6810
#
# Time taken for the epoch 33.5781
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.1311
# Batch 100 Loss 0.1215
# Batch 200 Loss 0.1111
# Batch 300 Loss 0.1145
#
# Validating ...
#
# Train Loss: 0.1188 Train Accuracy: 96.1512 Validation Loss: 1.4507 Validation Accuracy: 79.9724
#
# Time taken for the epoch 33.6990
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.1027
# Batch 100 Loss 0.0937
# Batch 200 Loss 0.1045
# Batch 300 Loss 0.0908
#
# Validating ...
#
# Train Loss: 0.1025 Train Accuracy: 96.6691 Validation Loss: 1.6850 Validation Accuracy: 77.9319
#
# Time taken for the epoch 33.6333
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.0872
# Batch 100 Loss 0.1037
# Batch 200 Loss 0.0902
# Batch 300 Loss 0.0969
#
# Validating ...
#
# Train Loss: 0.0888 Train Accuracy: 97.1254 Validation Loss: 1.4801 Validation Accuracy: 80.9323
#
# Time taken for the epoch 33.5019
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.0680
# Batch 100 Loss 0.0886
# Batch 200 Loss 0.0693
# Batch 300 Loss 0.0730
#
# Validating ...
#
# Train Loss: 0.0772 Train Accuracy: 97.5967 Validation Loss: 1.5523 Validation Accuracy: 81.1689
#
# Time taken for the epoch 33.7374
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.0660
# Batch 100 Loss 0.0606
# Batch 200 Loss 0.0621
# Batch 300 Loss 0.0653
#
# Validating ...
#
# Train Loss: 0.0671 Train Accuracy: 97.8608 Validation Loss: 1.5814 Validation Accuracy: 80.2154
#
# Time taken for the epoch 33.6324
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.0604
# Batch 100 Loss 0.0582
# Batch 200 Loss 0.0601
# Batch 300 Loss 0.0809
#
# Validating ...
#
# Train Loss: 0.0598 Train Accuracy: 98.1193 Validation Loss: 1.6194 Validation Accuracy: 80.5338
#
# Time taken for the epoch 34.1151
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.0436
# Batch 100 Loss 0.0423
# Batch 200 Loss 0.0539
# Batch 300 Loss 0.0575
#
# Validating ...
#
# Train Loss: 0.0525 Train Accuracy: 98.3765 Validation Loss: 1.6030 Validation Accuracy: 81.3437
#
# Time taken for the epoch 33.9600
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.0466
# Batch 100 Loss 0.0392
# Batch 200 Loss 0.0494
# Batch 300 Loss 0.0477
#
# Validating ...
#
# Train Loss: 0.0480 Train Accuracy: 98.4652 Validation Loss: 1.6402 Validation Accuracy: 81.2530
#
# Time taken for the epoch 33.5639
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.0346
# Batch 100 Loss 0.0381
# Batch 200 Loss 0.0423
# Batch 300 Loss 0.0346
#
# Validating ...
#
# Train Loss: 0.0431 Train Accuracy: 98.6438 Validation Loss: 1.6913 Validation Accuracy: 81.2040
#
# Time taken for the epoch 33.6019
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.0368
# Batch 100 Loss 0.0392
# Batch 200 Loss 0.0335
# Batch 300 Loss 0.0448
#
# Validating ...
#
# Train Loss: 0.0385 Train Accuracy: 98.7963 Validation Loss: 1.6791 Validation Accuracy: 81.8292
#
# Time taken for the epoch 33.4570
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.0385
# Batch 100 Loss 0.0372
# Batch 200 Loss 0.0304
# Batch 300 Loss 0.0426
#
# Validating ...
#
# Train Loss: 0.0367 Train Accuracy: 98.8687 Validation Loss: 1.7422 Validation Accuracy: 80.6171
#
# Time taken for the epoch 33.9872
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
#
# Running test dataset through the model...
#
# Test Loss: 1.7095 Test Accuracy: 0.8138
# Word level accuracy: 0.3247445579742337

# %% [markdown]
# #Testing with attention

# %%
model2 = test_on_dataset(language="hi",
                        embedding_dim=256,
                        encoder_layers=3,
                        decoder_layers=3,
                        layer_type="lstm",
                        units=256,
                        dropout=0.2,
                        attention=True, save_outputs='predictions_attention.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9899
# Batch 100 Loss 1.0848
# Batch 200 Loss 0.9344
# Batch 300 Loss 0.8751
#
# Validating ...
#
# Train Loss: 1.0525 Train Accuracy: 68.1665 Validation Loss: 2.2913 Validation Accuracy: 52.4259
#
# Time taken for the epoch 136.9153
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.8645
# Batch 100 Loss 0.8185
# Batch 200 Loss 0.7586
# Batch 300 Loss 0.6920
#
# Validating ...
#
# Train Loss: 0.7778 Train Accuracy: 75.8738 Validation Loss: 2.4905 Validation Accuracy: 52.4783
#
# Time taken for the epoch 40.7995
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.6454
# Batch 100 Loss 0.6030
# Batch 200 Loss 0.5231
# Batch 300 Loss 0.4283
#
# Validating ...
#
# Train Loss: 0.5481 Train Accuracy: 80.8016 Validation Loss: 2.0416 Validation Accuracy: 63.8696
#
# Time taken for the epoch 40.5387
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.4359
# Batch 100 Loss 0.3820
# Batch 200 Loss 0.3202
# Batch 300 Loss 0.2508
#
# Validating ...
#
# Train Loss: 0.3223 Train Accuracy: 88.2654 Validation Loss: 1.6289 Validation Accuracy: 74.3812
#
# Time taken for the epoch 40.6603
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.2343
# Batch 100 Loss 0.2222
# Batch 200 Loss 0.2054
# Batch 300 Loss 0.1653
#
# Validating ...
#
# Train Loss: 0.2040 Train Accuracy: 92.9120 Validation Loss: 1.3965 Validation Accuracy: 80.2425
#
# Time taken for the epoch 40.6864
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.1561
# Batch 100 Loss 0.1516
# Batch 200 Loss 0.1665
# Batch 300 Loss 0.1511
#
# Validating ...
#
# Train Loss: 0.1567 Train Accuracy: 94.6919 Validation Loss: 1.3201 Validation Accuracy: 81.9170
#
# Time taken for the epoch 39.6574
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.1401
# Batch 100 Loss 0.1189
# Batch 200 Loss 0.1205
# Batch 300 Loss 0.1172
#
# Validating ...
#
# Train Loss: 0.1323 Train Accuracy: 95.5917 Validation Loss: 1.3292 Validation Accuracy: 82.0620
#
# Time taken for the epoch 39.9569
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.1105
# Batch 100 Loss 0.0932
# Batch 200 Loss 0.1066
# Batch 300 Loss 0.1156
#
# Validating ...
#
# Train Loss: 0.1140 Train Accuracy: 96.1758 Validation Loss: 1.2293 Validation Accuracy: 83.6072
#
# Time taken for the epoch 40.7432
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.1030
# Batch 100 Loss 0.1077
# Batch 200 Loss 0.0984
# Batch 300 Loss 0.1127
#
# Validating ...
#
# Train Loss: 0.1010 Train Accuracy: 96.6487 Validation Loss: 1.2774 Validation Accuracy: 83.9196
#
# Time taken for the epoch 40.5818
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.0895
# Batch 100 Loss 0.0828
# Batch 200 Loss 0.0846
# Batch 300 Loss 0.1066
#
# Validating ...
#
# Train Loss: 0.0895 Train Accuracy: 97.0328 Validation Loss: 1.2613 Validation Accuracy: 83.6757
#
# Time taken for the epoch 40.3138
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.0656
# Batch 100 Loss 0.0704
# Batch 200 Loss 0.0680
# Batch 300 Loss 0.0938
#
# Validating ...
#
# Train Loss: 0.0801 Train Accuracy: 97.3734 Validation Loss: 1.3035 Validation Accuracy: 84.1337
#
# Time taken for the epoch 39.8961
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.0702
# Batch 100 Loss 0.0853
# Batch 200 Loss 0.0656
# Batch 300 Loss 0.0772
#
# Validating ...
#
# Train Loss: 0.0705 Train Accuracy: 97.6674 Validation Loss: 1.3189 Validation Accuracy: 84.1395
#
# Time taken for the epoch 39.5242
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.0557
# Batch 100 Loss 0.0605
# Batch 200 Loss 0.0550
# Batch 300 Loss 0.0742
#
# Validating ...
#
# Train Loss: 0.0638 Train Accuracy: 97.9114 Validation Loss: 1.3400 Validation Accuracy: 84.3454
#
# Time taken for the epoch 39.8093
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.0604
# Batch 100 Loss 0.0642
# Batch 200 Loss 0.0539
# Batch 300 Loss 0.0574
#
# Validating ...
#
# Train Loss: 0.0572 Train Accuracy: 98.1356 Validation Loss: 1.3579 Validation Accuracy: 84.5560
#
# Time taken for the epoch 39.7916
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.0509
# Batch 100 Loss 0.0442
# Batch 200 Loss 0.0635
# Batch 300 Loss 0.0629
#
# Validating ...
#
# Train Loss: 0.0526 Train Accuracy: 98.2814 Validation Loss: 1.4260 Validation Accuracy: 84.1198
#
# Time taken for the epoch 39.8162
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.0604
# Batch 100 Loss 0.0446
# Batch 200 Loss 0.0465
# Batch 300 Loss 0.0474
#
# Validating ...
#
# Train Loss: 0.0481 Train Accuracy: 98.3622 Validation Loss: 1.3890 Validation Accuracy: 84.3250
#
# Time taken for the epoch 39.7944
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.0406
# Batch 100 Loss 0.0524
# Batch 200 Loss 0.0413
# Batch 300 Loss 0.0545
#
# Validating ...
#
# Train Loss: 0.0428 Train Accuracy: 98.5581 Validation Loss: 1.4565 Validation Accuracy: 83.6219
#
# Time taken for the epoch 39.8006
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.0294
# Batch 100 Loss 0.0343
# Batch 200 Loss 0.0491
# Batch 300 Loss 0.0404
#
# Validating ...
#
# Train Loss: 0.0410 Train Accuracy: 98.6891 Validation Loss: 1.4294 Validation Accuracy: 85.0730
#
# Time taken for the epoch 39.5238
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.0372
# Batch 100 Loss 0.0360
# Batch 200 Loss 0.0421
# Batch 300 Loss 0.0340
#
# Validating ...
#
# Train Loss: 0.0379 Train Accuracy: 98.7088 Validation Loss: 1.4877 Validation Accuracy: 84.1925
#
# Time taken for the epoch 40.3109
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.0299
# Batch 100 Loss 0.0269
# Batch 200 Loss 0.0322
# Batch 300 Loss 0.0350
#
# Validating ...
#
# Train Loss: 0.0345 Train Accuracy: 98.8895 Validation Loss: 1.5233 Validation Accuracy: 84.4055
#
# Time taken for the epoch 40.8987
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
#
# Running test dataset through the model...
#
# Test Loss: 1.5324 Test Accuracy: 0.8436
# Word level accuracy: 0.370501999111506

# %%
def get_test_words(n):
    test_df = pd.read_csv(get_data_files("hi")[2])
    test_sample = test_df.sample(n)
    test_sample.reset_index(inplace=True, drop=True)
    test_words = []
    for i in test_sample.index:
        entry = test_sample["अंक\tank\t5"].loc[i]
        parts = entry.split("\t")
        word = parts[1]
        test_words.append(word)
    return test_words

test_words = get_test_words(5)
print(test_words)
# Out:
# ['teekamgarh', 'sandli', 'singer', 'brahmleen', 'sandrbh']

# %%
for word in test_words:
    visualise_connectivity(model2, word, activation="scaler")
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Original Word: teekamgarh
# Transliterated Word: तीकामगढ़
# Connectivity Visualization for त :
# <text style=color:#000;background-color:#f68f8f>t </text><text style=color:#000;background-color:#f42e2e>e </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>e </text><text style=color:#000;background-color:#89c4e2>k </text><text style=color:#000;background-color:#89c4e2>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>a </text><text style=color:#000;background-color:#95cae5>r </text><text style=color:#000;background-color:#95cae5>h </text>
# Connectivity Visualization for ी :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#99cce6>e </text><text style=color:#000;background-color:#f47676>e </text><text style=color:#000;background-color:#f42e2e>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for क :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#f42e2e>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for म :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for ग :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for ढ :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for ़ :
# <text style=color:#000;background-color:#85c2e1>t </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>k </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>h </text>
# Original Word: sandli
# Transliterated Word: सांडली
# Connectivity Visualization for स :
# <text style=color:#000;background-color:#f34343>s </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>n </text><text style=color:#000;background-color:#89c4e2>d </text><text style=color:#000;background-color:#c2e1f0>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ा :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#99cce6>n </text><text style=color:#000;background-color:#f42e2e>d </text><text style=color:#000;background-color:#f47676>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ं :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>d </text><text style=color:#000;background-color:#f42e2e>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ड :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ल :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Connectivity Visualization for ी :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>i </text>
# Original Word: singer
# Transliterated Word: सिंगर
# Connectivity Visualization for स :
# <text style=color:#000;background-color:#f42e2e>s </text><text style=color:#000;background-color:#f34343>i </text><text style=color:#000;background-color:#99cce6>n </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;background-color:#f47676>e </text><text style=color:#000;background-color:#85c2e1>r </text>
# Connectivity Visualization for ि :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#f42e2e>n </text><text style=color:#000;background-color:#c2e1f0>g </text><text style=color:#000;background-color:#baddee>e </text><text style=color:#000;background-color:#85c2e1>r </text>
# Connectivity Visualization for ं :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;background-color:#f42e2e>e </text><text style=color:#000;background-color:#85c2e1>r </text>
# Connectivity Visualization for ग :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>r </text>
# Connectivity Visualization for र :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>i </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>g </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>r </text>
# Original Word: brahmleen
# Transliterated Word: ब्रह्मलीन
# Connectivity Visualization for ब :
# <text style=color:#000;background-color:#f68f8f>b </text><text style=color:#000;background-color:#f42e2e>r </text><text style=color:#000;background-color:#95cae5>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#89c4e2>m </text><text style=color:#000;background-color:#eff7fb>l </text><text style=color:#000;background-color:#95cae5>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#89c4e2>r </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for र :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#89c4e2>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ह :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ् :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for म :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ल :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for ी :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Connectivity Visualization for न :
# <text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>h </text><text style=color:#000;background-color:#85c2e1>m </text><text style=color:#000;background-color:#85c2e1>l </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>e </text><text style=color:#000;background-color:#85c2e1>n </text>
# Original Word: sandrbh
# Transliterated Word: संदृभ
# Connectivity Visualization for स :
# <text style=color:#000;background-color:#f42e2e>s </text><text style=color:#000;background-color:#f42e2e>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#a1d0e8#b2d9ec>d </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#c2e1f0>b </text><text style=color:#000;background-color:#99cce6>h </text>
# Connectivity Visualization for ं :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#baddee>n </text><text style=color:#000;background-color:#f42e2e>d </text><text style=color:#000;background-color:#95cae5>r </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for द :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#f42e2e>d </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for ृ :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>h </text>
# Connectivity Visualization for भ :
# <text style=color:#000;background-color:#85c2e1>s </text><text style=color:#000;background-color:#85c2e1>a </text><text style=color:#000;background-color:#85c2e1>n </text><text style=color:#000;background-color:#85c2e1>d </text><text style=color:#000;background-color:#85c2e1>r </text><text style=color:#000;background-color:#85c2e1>b </text><text style=color:#000;background-color:#85c2e1>h </text>

# %%
randomly_evaluate(model, n=5)
# Out:
# Randomly evaluating the model on 5 words
#
# Input word: nihaalchand
# Actual translation: निहालचंद
# Model translation: निहीलचंद
#
# Input word: paheliyan
# Actual translation: पहेलियां
# Model translation: पहिलियां
#
# Input word: then
# Actual translation: थेन
# Model translation: थें
#
# Input word: batlaakar
# Actual translation: बतलाकर
# Model translation: बतलाकर
#
# Input word: nabj
# Actual translation: नब्ज़
# Model translation: नबाज

# %%
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# #WandB training

# %%
def train_with_wandb(language):

    config_defaults = {"embedding_dim": 64, 
                       "enc_dec_layers": 1,
                       "layer_type": "lstm",
                       "units": 128,
                       "dropout": 0,
                       "attention": False,
                       "teacher_forcing_ratio": 1.0
                       }

    wandb.init(config=config_defaults, project="cs6910-assignment3", resume=True)
    # Below is an example of a custom run name for sweep 4
    # This line was different for all sweeps

    ## 1. SELECT LANGUAGE ##
    TRAIN_TSV, VAL_TSV, TEST_TSV = get_data_files(language)

    ## 2. DATA PREPROCESSING ##
    dataset, input_tokenizer, targ_tokenizer = preprocess_data(TRAIN_TSV)
    val_dataset, _, _ = preprocess_data(VAL_TSV, input_tokenizer, targ_tokenizer)

    ## 3. CREATING THE MODEL ##
    model = Seq2SeqModel(embedding_dim=wandb.config.embedding_dim,
                         encoder_layers=wandb.config.enc_dec_layers,
                         decoder_layers=wandb.config.enc_dec_layers,
                         layer_type=wandb.config.layer_type,
                         units=wandb.config.units,
                         dropout=wandb.config.dropout,
                         attention=wandb.config.attention)
    
    ## 4. COMPILING THE MODEL 
    model.set_vocabulary(input_tokenizer, targ_tokenizer)
    model.build(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metric = tf.keras.metrics.SparseCategoricalAccuracy())
    
    ## 5. FITTING AND VALIDATING THE MODEL
    model.fit(dataset, val_dataset, epochs=20, use_wandb=True, teacher_forcing_ratio=wandb.config.teacher_forcing_ratio)

# %% [markdown]
# #First sweep

# %%
sweep_config = {
  "name": "Sweep 1- Assignment3",
  "method": "grid",
  "parameters": {
        "enc_dec_layers": {
           "values": [1, 2, 3]
        },
        "units": {
            "values": [64, 128, 256]
        },
        "layer_type": {
            "values": ["rnn", "gru", "lstm"]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project="cs6910-assignment3")
# Out:
# Create sweep with ID: l64qp4dv
# Sweep URL: https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv

# %%
wandb.agent(sweep_id, function=lambda: train_with_wandb("hi"))
# Out:
# wandb: Agent Starting Run: s15251gu with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: rnn
# wandb: 	units: 64
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Tried to auto resume run with id wqwfmy1i but id s15251gu is set.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_154730-s15251gu</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/s15251gu" target="_blank">rich-sweep-1</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 4.0162
# Batch 100 Loss 1.1844
# Batch 200 Loss 1.0742
# Batch 300 Loss 0.9797
#
# Validating ...
#
# Train Loss: 1.2067 Train Accuracy: 63.2089 Validation Loss: 2.3059 Validation Accuracy: 47.9538
#
# Time taken for the epoch 27.4635
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9280
# Batch 100 Loss 0.9105
# Batch 200 Loss 0.8629
# Batch 300 Loss 0.8310
#
# Validating ...
#
# Train Loss: 0.8789 Train Accuracy: 74.9216 Validation Loss: 2.6213 Validation Accuracy: 48.3824
#
# Time taken for the epoch 12.8931
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8129
# Batch 100 Loss 0.8283
# Batch 200 Loss 0.7775
# Batch 300 Loss 0.7671
#
# Validating ...
#
# Train Loss: 0.8017 Train Accuracy: 77.0058 Validation Loss: 2.8256 Validation Accuracy: 47.8041
#
# Time taken for the epoch 12.6975
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.7537
# Batch 100 Loss 0.7804
# Batch 200 Loss 0.7195
# Batch 300 Loss 0.7871
#
# Validating ...
#
# Train Loss: 0.7490 Train Accuracy: 78.4882 Validation Loss: 2.9112 Validation Accuracy: 49.0684
#
# Time taken for the epoch 12.6752
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.7584
# Batch 100 Loss 0.7235
# Batch 200 Loss 0.7252
# Batch 300 Loss 0.6827
#
# Validating ...
#
# Train Loss: 0.7090 Train Accuracy: 79.5449 Validation Loss: 3.5683 Validation Accuracy: 43.7406
#
# Time taken for the epoch 13.0644
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.7123
# Batch 100 Loss 0.6732
# Batch 200 Loss 0.6722
# Batch 300 Loss 0.6690
#
# Validating ...
#
# Train Loss: 0.6770 Train Accuracy: 80.1066 Validation Loss: 3.6459 Validation Accuracy: 43.2240
#
# Time taken for the epoch 12.6520
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.6441
# Batch 100 Loss 0.6667
# Batch 200 Loss 0.6676
# Batch 300 Loss 0.7213
#
# Validating ...
#
# Train Loss: 0.6531 Train Accuracy: 80.7197 Validation Loss: 3.8001 Validation Accuracy: 42.7907
#
# Time taken for the epoch 12.6530
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.5674
# Batch 100 Loss 0.6301
# Batch 200 Loss 0.6558
# Batch 300 Loss 0.6432
#
# Validating ...
#
# Train Loss: 0.6326 Train Accuracy: 81.2635 Validation Loss: 3.9770 Validation Accuracy: 41.3450
#
# Time taken for the epoch 12.7100
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.6113
# Batch 100 Loss 0.5980
# Batch 200 Loss 0.6201
# Batch 300 Loss 0.5899
#
# Validating ...
#
# Train Loss: 0.6155 Train Accuracy: 81.6043 Validation Loss: 3.8418 Validation Accuracy: 43.9240
#
# Time taken for the epoch 12.6821
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.5947
# Batch 100 Loss 0.5655
# Batch 200 Loss 0.5631
# Batch 300 Loss 0.5883
#
# Validating ...
#
# Train Loss: 0.5996 Train Accuracy: 81.9177 Validation Loss: 4.0106 Validation Accuracy: 43.1019
#
# Time taken for the epoch 12.8165
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.5660
# Batch 100 Loss 0.5849
# Batch 200 Loss 0.6108
# Batch 300 Loss 0.5872
#
# Validating ...
#
# Train Loss: 0.5876 Train Accuracy: 82.1500 Validation Loss: 3.8421 Validation Accuracy: 45.6349
#
# Time taken for the epoch 12.8507
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.5574
# Batch 100 Loss 0.5899
# Batch 200 Loss 0.5358
# Batch 300 Loss 0.5536
#
# Validating ...
#
# Train Loss: 0.5747 Train Accuracy: 82.5405 Validation Loss: 4.0745 Validation Accuracy: 43.5550
#
# Time taken for the epoch 12.6093
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.5955
# Batch 100 Loss 0.6134
# Batch 200 Loss 0.5246
# Batch 300 Loss 0.5810
#
# Validating ...
#
# Train Loss: 0.5654 Train Accuracy: 82.6547 Validation Loss: 4.2045 Validation Accuracy: 42.7111
#
# Time taken for the epoch 12.7330
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.5747
# Batch 100 Loss 0.5204
# Batch 200 Loss 0.5289
# Batch 300 Loss 0.5809
#
# Validating ...
#
# Train Loss: 0.5562 Train Accuracy: 82.8945 Validation Loss: 4.3118 Validation Accuracy: 42.5779
#
# Time taken for the epoch 12.9551
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.5599
# Batch 100 Loss 0.5465
# Batch 200 Loss 0.5569
# Batch 300 Loss 0.5762
#
# Validating ...
#
# Train Loss: 0.5474 Train Accuracy: 83.0711 Validation Loss: 4.2799 Validation Accuracy: 43.7210
#
# Time taken for the epoch 12.7912
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.5763
# Batch 100 Loss 0.5300
# Batch 200 Loss 0.4939
# Batch 300 Loss 0.5572
#
# Validating ...
#
# Train Loss: 0.5396 Train Accuracy: 83.3084 Validation Loss: 4.3377 Validation Accuracy: 43.5649
#
# Time taken for the epoch 12.7028
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.5438
# Batch 100 Loss 0.5494
# Batch 200 Loss 0.5124
# Batch 300 Loss 0.5346
#
# Validating ...
#
# Train Loss: 0.5331 Train Accuracy: 83.4151 Validation Loss: 4.5956 Validation Accuracy: 41.9808
#
# Time taken for the epoch 12.9748
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.5392
# Batch 100 Loss 0.4985
# Batch 200 Loss 0.5660
# Batch 300 Loss 0.5106
#
# Validating ...
#
# Train Loss: 0.5260 Train Accuracy: 83.6919 Validation Loss: 4.3436 Validation Accuracy: 44.6037
#
# Time taken for the epoch 12.6962
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.5173
# Batch 100 Loss 0.5361
# Batch 200 Loss 0.5193
# Batch 300 Loss 0.6193
#
# Validating ...
#
# Train Loss: 0.5203 Train Accuracy: 83.8432 Validation Loss: 4.5460 Validation Accuracy: 42.9708
#
# Time taken for the epoch 12.7222
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.5043
# Batch 100 Loss 0.5294
# Batch 200 Loss 0.5118
# Batch 300 Loss 0.5025
#
# Validating ...
#
# Train Loss: 0.5141 Train Accuracy: 83.9275 Validation Loss: 4.4729 Validation Accuracy: 44.0669
#
# Time taken for the epoch 13.0019
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▅▆▆▇▇▇▇▇▇▇█████████</td></tr><tr><td>train loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▇▇▇█▃▃▂▁▃▃▅▃▂▂▃▃▂▄▂▃</td></tr><tr><td>val loss</td><td>▁▂▃▃▅▅▆▆▆▆▆▆▇▇▇▇█▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>83.92747</td></tr><tr><td>train loss</td><td>0.51406</td></tr><tr><td>training time</td><td>13.00186</td></tr><tr><td>val acc</td><td>44.06693</td></tr><tr><td>val loss</td><td>4.47287</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rich-sweep-1</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/s15251gu" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/s15251gu</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_154730-s15251gu/logs</code>
# wandb: Agent Starting Run: 2bxog4mc with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: rnn
# wandb: 	units: 128
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_155221-2bxog4mc</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/2bxog4mc" target="_blank">drawn-sweep-2</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 4.0132
# Batch 100 Loss 1.0891
# Batch 200 Loss 1.0175
# Batch 300 Loss 0.9905
#
# Validating ...
#
# Train Loss: 1.1449 Train Accuracy: 65.9362 Validation Loss: 3.4433 Validation Accuracy: 36.5478
#
# Time taken for the epoch 29.1032
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9687
# Batch 100 Loss 0.9336
# Batch 200 Loss 0.9290
# Batch 300 Loss 0.9605
#
# Validating ...
#
# Train Loss: 0.9431 Train Accuracy: 73.0482 Validation Loss: 3.5167 Validation Accuracy: 36.1969
#
# Time taken for the epoch 14.8346
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.9328
# Batch 100 Loss 0.8830
# Batch 200 Loss 0.9686
# Batch 300 Loss 0.9186
#
# Validating ...
#
# Train Loss: 0.9145 Train Accuracy: 73.4536 Validation Loss: 3.0406 Validation Accuracy: 42.4505
#
# Time taken for the epoch 14.6691
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.9051
# Batch 100 Loss 0.8888
# Batch 200 Loss 0.8613
# Batch 300 Loss 0.8855
#
# Validating ...
#
# Train Loss: 0.8960 Train Accuracy: 73.8239 Validation Loss: 3.8702 Validation Accuracy: 36.2894
#
# Time taken for the epoch 14.5570
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.8852
# Batch 100 Loss 0.8505
# Batch 200 Loss 0.9051
# Batch 300 Loss 0.8567
#
# Validating ...
#
# Train Loss: 0.8826 Train Accuracy: 74.1545 Validation Loss: 3.2249 Validation Accuracy: 42.2521
#
# Time taken for the epoch 14.7132
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.8608
# Batch 100 Loss 0.8683
# Batch 200 Loss 0.8788
# Batch 300 Loss 0.8922
#
# Validating ...
#
# Train Loss: 0.8712 Train Accuracy: 74.3656 Validation Loss: 3.2522 Validation Accuracy: 42.1060
#
# Time taken for the epoch 14.6281
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.8302
# Batch 100 Loss 0.8540
# Batch 200 Loss 0.8725
# Batch 300 Loss 0.8407
#
# Validating ...
#
# Train Loss: 0.8616 Train Accuracy: 74.6528 Validation Loss: 3.5466 Validation Accuracy: 41.9823
#
# Time taken for the epoch 14.4904
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.8480
# Batch 100 Loss 0.8817
# Batch 200 Loss 0.8663
# Batch 300 Loss 0.8532
#
# Validating ...
#
# Train Loss: 0.8536 Train Accuracy: 74.8691 Validation Loss: 3.6082 Validation Accuracy: 41.9247
#
# Time taken for the epoch 14.7204
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.8347
# Batch 100 Loss 0.8394
# Batch 200 Loss 0.8196
# Batch 300 Loss 0.8025
#
# Validating ...
#
# Train Loss: 0.8457 Train Accuracy: 75.0740 Validation Loss: 2.8918 Validation Accuracy: 52.7611
#
# Time taken for the epoch 14.5759
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.8552
# Batch 100 Loss 0.8431
# Batch 200 Loss 0.8179
# Batch 300 Loss 0.8588
#
# Validating ...
#
# Train Loss: 0.8393 Train Accuracy: 75.2134 Validation Loss: 5.0308 Validation Accuracy: 35.7359
#
# Time taken for the epoch 14.8132
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.8143
# Batch 100 Loss 0.8305
# Batch 200 Loss 0.8379
# Batch 300 Loss 0.8490
#
# Validating ...
#
# Train Loss: 0.8330 Train Accuracy: 75.4977 Validation Loss: 2.7067 Validation Accuracy: 52.9450
#
# Time taken for the epoch 14.5632
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.7778
# Batch 100 Loss 0.8171
# Batch 200 Loss 0.8515
# Batch 300 Loss 0.8053
#
# Validating ...
#
# Train Loss: 0.8272 Train Accuracy: 75.5793 Validation Loss: 3.9254 Validation Accuracy: 41.9355
#
# Time taken for the epoch 14.6791
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.8118
# Batch 100 Loss 0.8283
# Batch 200 Loss 0.8493
# Batch 300 Loss 0.8484
#
# Validating ...
#
# Train Loss: 0.8220 Train Accuracy: 75.7255 Validation Loss: 3.9531 Validation Accuracy: 42.0728
#
# Time taken for the epoch 14.7050
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.8157
# Batch 100 Loss 0.8547
# Batch 200 Loss 0.8443
# Batch 300 Loss 0.7910
#
# Validating ...
#
# Train Loss: 0.8172 Train Accuracy: 75.8634 Validation Loss: 3.1347 Validation Accuracy: 51.9959
#
# Time taken for the epoch 14.5867
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.8096
# Batch 100 Loss 0.7985
# Batch 200 Loss 0.8257
# Batch 300 Loss 0.8168
#
# Validating ...
#
# Train Loss: 0.8128 Train Accuracy: 75.9324 Validation Loss: 4.0821 Validation Accuracy: 41.7600
#
# Time taken for the epoch 14.7021
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.8109
# Batch 100 Loss 0.8273
# Batch 200 Loss 0.7901
# Batch 300 Loss 0.8238
#
# Validating ...
#
# Train Loss: 0.8087 Train Accuracy: 76.0546 Validation Loss: 4.1110 Validation Accuracy: 41.7860
#
# Time taken for the epoch 14.7050
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.8023
# Batch 100 Loss 0.8229
# Batch 200 Loss 0.8308
# Batch 300 Loss 0.8065
#
# Validating ...
#
# Train Loss: 0.8048 Train Accuracy: 76.2025 Validation Loss: 4.0103 Validation Accuracy: 41.7158
#
# Time taken for the epoch 14.6236
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.8431
# Batch 100 Loss 0.8087
# Batch 200 Loss 0.8252
# Batch 300 Loss 0.7990
#
# Validating ...
#
# Train Loss: 0.8014 Train Accuracy: 76.2451 Validation Loss: 4.0777 Validation Accuracy: 42.0057
#
# Time taken for the epoch 14.7494
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.7759
# Batch 100 Loss 0.8259
# Batch 200 Loss 0.7851
# Batch 300 Loss 0.7696
#
# Validating ...
#
# Train Loss: 0.7979 Train Accuracy: 76.3991 Validation Loss: 5.5328 Validation Accuracy: 35.5841
#
# Time taken for the epoch 14.8786
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.8153
# Batch 100 Loss 0.7541
# Batch 200 Loss 0.7897
# Batch 300 Loss 0.7943
#
# Validating ...
#
# Train Loss: 0.7948 Train Accuracy: 76.4749 Validation Loss: 4.3098 Validation Accuracy: 41.7006
#
# Time taken for the epoch 14.6585
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▆▆▆▆▇▇▇▇▇▇▇████████</td></tr><tr><td>train loss</td><td>█▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▁▄▁▄▄▄▄█▁█▄▄█▃▄▃▄▁▃</td></tr><tr><td>val loss</td><td>▃▃▂▄▂▂▃▃▁▇▁▄▄▂▄▄▄▄█▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>76.47495</td></tr><tr><td>train loss</td><td>0.79476</td></tr><tr><td>training time</td><td>14.65854</td></tr><tr><td>val acc</td><td>41.70057</td></tr><tr><td>val loss</td><td>4.30977</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">drawn-sweep-2</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/2bxog4mc" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/2bxog4mc</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_155221-2bxog4mc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bq5ffc8f with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: rnn
# wandb: 	units: 256
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_155803-bq5ffc8f</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/bq5ffc8f" target="_blank">vivid-sweep-3</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9732
# Batch 100 Loss 1.1061
# Batch 200 Loss 0.9567
# Batch 300 Loss 0.9664
#
# Validating ...
#
# Train Loss: 1.0976 Train Accuracy: 67.2981 Validation Loss: 2.2364 Validation Accuracy: 53.2103
#
# Time taken for the epoch 30.8828
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9278
# Batch 100 Loss 0.9633
# Batch 200 Loss 0.8982
# Batch 300 Loss 0.8816
#
# Validating ...
#
# Train Loss: 0.9320 Train Accuracy: 73.1107 Validation Loss: 2.4037 Validation Accuracy: 56.0731
#
# Time taken for the epoch 15.5107
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8958
# Batch 100 Loss 0.8967
# Batch 200 Loss 0.9257
# Batch 300 Loss 0.9080
#
# Validating ...
#
# Train Loss: 0.9027 Train Accuracy: 73.6261 Validation Loss: 4.0472 Validation Accuracy: 36.2760
#
# Time taken for the epoch 15.6378
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8832
# Batch 100 Loss 0.8892
# Batch 200 Loss 0.8879
# Batch 300 Loss 0.8830
#
# Validating ...
#
# Train Loss: 0.8820 Train Accuracy: 74.0926 Validation Loss: 3.2603 Validation Accuracy: 47.8386
#
# Time taken for the epoch 15.4634
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.8628
# Batch 100 Loss 0.8311
# Batch 200 Loss 0.8454
# Batch 300 Loss 0.8883
#
# Validating ...
#
# Train Loss: 0.8641 Train Accuracy: 74.5053 Validation Loss: 2.8689 Validation Accuracy: 56.3471
#
# Time taken for the epoch 15.6117
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.8664
# Batch 100 Loss 0.8335
# Batch 200 Loss 0.8552
# Batch 300 Loss 0.8673
#
# Validating ...
#
# Train Loss: 0.8490 Train Accuracy: 74.9814 Validation Loss: 4.3484 Validation Accuracy: 36.1468
#
# Time taken for the epoch 15.4497
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.8332
# Batch 100 Loss 0.8214
# Batch 200 Loss 0.8084
# Batch 300 Loss 0.8725
#
# Validating ...
#
# Train Loss: 0.8346 Train Accuracy: 75.2928 Validation Loss: 2.7136 Validation Accuracy: 55.2523
#
# Time taken for the epoch 15.6232
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.8284
# Batch 100 Loss 0.8473
# Batch 200 Loss 0.7622
# Batch 300 Loss 0.8162
#
# Validating ...
#
# Train Loss: 0.8222 Train Accuracy: 75.7017 Validation Loss: 5.9186 Validation Accuracy: 22.6824
#
# Time taken for the epoch 15.4446
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.8180
# Batch 100 Loss 0.8264
# Batch 200 Loss 0.8209
# Batch 300 Loss 0.8067
#
# Validating ...
#
# Train Loss: 0.8102 Train Accuracy: 76.0147 Validation Loss: 2.7750 Validation Accuracy: 55.1614
#
# Time taken for the epoch 15.4016
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.8269
# Batch 100 Loss 0.7572
# Batch 200 Loss 0.7818
# Batch 300 Loss 0.8018
#
# Validating ...
#
# Train Loss: 0.7993 Train Accuracy: 76.2710 Validation Loss: 4.6042 Validation Accuracy: 35.5579
#
# Time taken for the epoch 15.5097
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.7687
# Batch 100 Loss 0.7814
# Batch 200 Loss 0.7942
# Batch 300 Loss 0.7778
#
# Validating ...
#
# Train Loss: 0.7888 Train Accuracy: 76.6148 Validation Loss: 6.7979 Validation Accuracy: 22.3237
#
# Time taken for the epoch 15.4099
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.7726
# Batch 100 Loss 0.7869
# Batch 200 Loss 0.7776
# Batch 300 Loss 0.7622
#
# Validating ...
#
# Train Loss: 0.7792 Train Accuracy: 76.8189 Validation Loss: 3.1553 Validation Accuracy: 52.5524
#
# Time taken for the epoch 15.6820
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.7750
# Batch 100 Loss 0.7469
# Batch 200 Loss 0.7796
# Batch 300 Loss 0.7667
#
# Validating ...
#
# Train Loss: 0.7701 Train Accuracy: 77.0168 Validation Loss: 2.9312 Validation Accuracy: 55.4126
#
# Time taken for the epoch 15.4210
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.7577
# Batch 100 Loss 0.7839
# Batch 200 Loss 0.7769
# Batch 300 Loss 0.7400
#
# Validating ...
#
# Train Loss: 0.7616 Train Accuracy: 77.3761 Validation Loss: 7.1677 Validation Accuracy: 22.4409
#
# Time taken for the epoch 15.3778
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.7348
# Batch 100 Loss 0.7521
# Batch 200 Loss 0.7512
# Batch 300 Loss 0.7646
#
# Validating ...
#
# Train Loss: 0.7541 Train Accuracy: 77.5127 Validation Loss: 7.5371 Validation Accuracy: 22.6757
#
# Time taken for the epoch 15.4259
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.7374
# Batch 100 Loss 0.7672
# Batch 200 Loss 0.7571
# Batch 300 Loss 0.7755
#
# Validating ...
#
# Train Loss: 0.7462 Train Accuracy: 77.7146 Validation Loss: 7.5567 Validation Accuracy: 22.4565
#
# Time taken for the epoch 15.4773
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.7561
# Batch 100 Loss 0.7489
# Batch 200 Loss 0.7415
# Batch 300 Loss 0.7379
#
# Validating ...
#
# Train Loss: 0.7398 Train Accuracy: 77.9165 Validation Loss: 3.2570 Validation Accuracy: 55.2878
#
# Time taken for the epoch 15.5274
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.7425
# Batch 100 Loss 0.7571
# Batch 200 Loss 0.7343
# Batch 300 Loss 0.7257
#
# Validating ...
#
# Train Loss: 0.7334 Train Accuracy: 78.0834 Validation Loss: 3.9659 Validation Accuracy: 47.5584
#
# Time taken for the epoch 15.1585
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.7413
# Batch 100 Loss 0.7197
# Batch 200 Loss 0.7335
# Batch 300 Loss 0.7021
#
# Validating ...
#
# Train Loss: 0.7277 Train Accuracy: 78.2646 Validation Loss: 8.0511 Validation Accuracy: 22.5338
#
# Time taken for the epoch 15.1369
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.7137
# Batch 100 Loss 0.7422
# Batch 200 Loss 0.7507
# Batch 300 Loss 0.7086
#
# Validating ...
#
# Train Loss: 0.7220 Train Accuracy: 78.3733 Validation Loss: 3.3687 Validation Accuracy: 53.0558
#
# Time taken for the epoch 15.2441
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▅▅▅▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>train loss</td><td>█▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▇█▄▆█▄█▁█▄▁▇█▁▁▁█▆▁▇</td></tr><tr><td>val loss</td><td>▁▁▃▂▂▄▂▅▂▄▆▂▂▇▇▇▂▃█▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>78.37331</td></tr><tr><td>train loss</td><td>0.72196</td></tr><tr><td>training time</td><td>15.24405</td></tr><tr><td>val acc</td><td>53.05576</td></tr><tr><td>val loss</td><td>3.36873</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vivid-sweep-3</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/bq5ffc8f" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/bq5ffc8f</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_155803-bq5ffc8f/logs</code>
# wandb: Agent Starting Run: gt9vf7n6 with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: gru
# wandb: 	units: 64
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_160350-gt9vf7n6</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/gt9vf7n6" target="_blank">eager-sweep-4</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9850
# Batch 100 Loss 1.2311
# Batch 200 Loss 1.1029
# Batch 300 Loss 1.0380
#
# Validating ...
#
# Train Loss: 1.3463 Train Accuracy: 63.7597 Validation Loss: 2.7036 Validation Accuracy: 39.5280
#
# Time taken for the epoch 38.5021
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 1.0102
# Batch 100 Loss 0.9028
# Batch 200 Loss 0.9406
# Batch 300 Loss 0.9363
#
# Validating ...
#
# Train Loss: 0.9465 Train Accuracy: 72.9261 Validation Loss: 2.6283 Validation Accuracy: 45.9883
#
# Time taken for the epoch 9.4675
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.9135
# Batch 100 Loss 0.9136
# Batch 200 Loss 0.8952
# Batch 300 Loss 0.9126
#
# Validating ...
#
# Train Loss: 0.8933 Train Accuracy: 74.1297 Validation Loss: 2.5158 Validation Accuracy: 48.0184
#
# Time taken for the epoch 9.4503
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8621
# Batch 100 Loss 0.9265
# Batch 200 Loss 0.8835
# Batch 300 Loss 0.9046
#
# Validating ...
#
# Train Loss: 0.8663 Train Accuracy: 74.8561 Validation Loss: 2.2076 Validation Accuracy: 53.9554
#
# Time taken for the epoch 9.4883
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.8788
# Batch 100 Loss 0.8856
# Batch 200 Loss 0.8683
# Batch 300 Loss 0.8825
#
# Validating ...
#
# Train Loss: 0.8479 Train Accuracy: 75.3270 Validation Loss: 2.4582 Validation Accuracy: 50.9800
#
# Time taken for the epoch 9.3140
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.8193
# Batch 100 Loss 0.8025
# Batch 200 Loss 0.7948
# Batch 300 Loss 0.8103
#
# Validating ...
#
# Train Loss: 0.8290 Train Accuracy: 75.7152 Validation Loss: 2.4309 Validation Accuracy: 52.7099
#
# Time taken for the epoch 9.6185
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.8028
# Batch 100 Loss 0.8175
# Batch 200 Loss 0.8487
# Batch 300 Loss 0.7962
#
# Validating ...
#
# Train Loss: 0.8067 Train Accuracy: 76.2049 Validation Loss: 2.7635 Validation Accuracy: 49.7782
#
# Time taken for the epoch 9.4496
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.7631
# Batch 100 Loss 0.7446
# Batch 200 Loss 0.7798
# Batch 300 Loss 0.7511
#
# Validating ...
#
# Train Loss: 0.7820 Train Accuracy: 76.8135 Validation Loss: 2.8777 Validation Accuracy: 48.3201
#
# Time taken for the epoch 9.3174
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.7401
# Batch 100 Loss 0.7968
# Batch 200 Loss 0.7737
# Batch 300 Loss 0.7163
#
# Validating ...
#
# Train Loss: 0.7509 Train Accuracy: 77.4947 Validation Loss: 2.7712 Validation Accuracy: 51.1000
#
# Time taken for the epoch 9.4967
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.7353
# Batch 100 Loss 0.7036
# Batch 200 Loss 0.6893
# Batch 300 Loss 0.6769
#
# Validating ...
#
# Train Loss: 0.7143 Train Accuracy: 78.4070 Validation Loss: 3.0413 Validation Accuracy: 48.6994
#
# Time taken for the epoch 9.5926
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.6678
# Batch 100 Loss 0.6969
# Batch 200 Loss 0.6830
# Batch 300 Loss 0.6491
#
# Validating ...
#
# Train Loss: 0.6779 Train Accuracy: 79.3277 Validation Loss: 2.9944 Validation Accuracy: 50.2325
#
# Time taken for the epoch 9.3081
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.6454
# Batch 100 Loss 0.6675
# Batch 200 Loss 0.6695
# Batch 300 Loss 0.6701
#
# Validating ...
#
# Train Loss: 0.6444 Train Accuracy: 80.2451 Validation Loss: 2.9237 Validation Accuracy: 51.5835
#
# Time taken for the epoch 9.4655
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.6751
# Batch 100 Loss 0.5844
# Batch 200 Loss 0.6109
# Batch 300 Loss 0.6542
#
# Validating ...
#
# Train Loss: 0.6188 Train Accuracy: 80.8812 Validation Loss: 3.0508 Validation Accuracy: 51.3990
#
# Time taken for the epoch 9.4836
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.5894
# Batch 100 Loss 0.5971
# Batch 200 Loss 0.5907
# Batch 300 Loss 0.5424
#
# Validating ...
#
# Train Loss: 0.5961 Train Accuracy: 81.6112 Validation Loss: 3.0135 Validation Accuracy: 53.0406
#
# Time taken for the epoch 9.4745
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.5838
# Batch 100 Loss 0.6165
# Batch 200 Loss 0.6030
# Batch 300 Loss 0.5708
#
# Validating ...
#
# Train Loss: 0.5719 Train Accuracy: 82.3330 Validation Loss: 2.9980 Validation Accuracy: 53.3816
#
# Time taken for the epoch 9.3895
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.5911
# Batch 100 Loss 0.5762
# Batch 200 Loss 0.5560
# Batch 300 Loss 0.5211
#
# Validating ...
#
# Train Loss: 0.5480 Train Accuracy: 82.9346 Validation Loss: 2.9910 Validation Accuracy: 54.2291
#
# Time taken for the epoch 9.4830
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.5725
# Batch 100 Loss 0.5071
# Batch 200 Loss 0.5560
# Batch 300 Loss 0.5247
#
# Validating ...
#
# Train Loss: 0.5256 Train Accuracy: 83.4950 Validation Loss: 3.0197 Validation Accuracy: 54.3002
#
# Time taken for the epoch 9.3352
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.5201
# Batch 100 Loss 0.5005
# Batch 200 Loss 0.4906
# Batch 300 Loss 0.4982
#
# Validating ...
#
# Train Loss: 0.5041 Train Accuracy: 84.1460 Validation Loss: 2.8794 Validation Accuracy: 56.2217
#
# Time taken for the epoch 9.5511
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.4676
# Batch 100 Loss 0.4711
# Batch 200 Loss 0.4551
# Batch 300 Loss 0.5033
#
# Validating ...
#
# Train Loss: 0.4850 Train Accuracy: 84.7476 Validation Loss: 2.8267 Validation Accuracy: 57.1534
#
# Time taken for the epoch 9.4524
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.4668
# Batch 100 Loss 0.4471
# Batch 200 Loss 0.4688
# Batch 300 Loss 0.4355
#
# Validating ...
#
# Train Loss: 0.4668 Train Accuracy: 85.3168 Validation Loss: 2.9654 Validation Accuracy: 56.4891
#
# Time taken for the epoch 9.4655
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>train loss</td><td>█▅▄▄▄▄▄▄▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▄▄▇▆▆▅▄▆▅▅▆▆▆▇▇▇███</td></tr><tr><td>val loss</td><td>▅▄▄▁▃▃▆▇▆██▇█████▇▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>85.31684</td></tr><tr><td>train loss</td><td>0.46682</td></tr><tr><td>training time</td><td>9.46548</td></tr><tr><td>val acc</td><td>56.48913</td></tr><tr><td>val loss</td><td>2.96542</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eager-sweep-4</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/gt9vf7n6" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/gt9vf7n6</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_160350-gt9vf7n6/logs</code>
# wandb: Agent Starting Run: zld7i4qy with config:
# wandb: 	enc_dec_layers: 1
# wandb: 	layer_type: gru
# wandb: 	units: 128
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_160750-zld7i4qy</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/zld7i4qy" target="_blank">dauntless-sweep-5</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9962
# Batch 100 Loss 1.2283
# Batch 200 Loss 1.0356
# Batch 300 Loss 0.9941
#
# Validating ...
#
# Train Loss: 1.2663 Train Accuracy: 64.8998 Validation Loss: 2.9369 Validation Accuracy: 38.5786
#
# Time taken for the epoch 40.9375
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9294
# Batch 100 Loss 0.9142
# Batch 200 Loss 0.8942
# Batch 300 Loss 0.9247
#
# Validating ...
#
# Train Loss: 0.9104 Train Accuracy: 73.6393 Validation Loss: 2.3318 Validation Accuracy: 51.6168
#
# Time taken for the epoch 11.0349
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.9365
# Batch 100 Loss 0.8527
# Batch 200 Loss 0.8397
# Batch 300 Loss 0.8541
#
# Validating ...
#
# Train Loss: 0.8669 Train Accuracy: 74.8236 Validation Loss: 2.5727 Validation Accuracy: 49.9351
#
# Time taken for the epoch 10.9977
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8351
# Batch 100 Loss 0.8614
# Batch 200 Loss 0.8436
# Batch 300 Loss 0.8513
#
# Validating ...
#
# Train Loss: 0.8386 Train Accuracy: 75.4552 Validation Loss: 3.2762 Validation Accuracy: 43.9849
#
# Time taken for the epoch 11.1548
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.8507
# Batch 100 Loss 0.8308
# Batch 200 Loss 0.8109
# Batch 300 Loss 0.7963
#
# Validating ...
#
# Train Loss: 0.8071 Train Accuracy: 76.0206 Validation Loss: 3.4398 Validation Accuracy: 43.8572
#
# Time taken for the epoch 11.0517
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.8285
# Batch 100 Loss 0.7937
# Batch 200 Loss 0.7473
# Batch 300 Loss 0.7909
#
# Validating ...
#
# Train Loss: 0.7713 Train Accuracy: 76.7541 Validation Loss: 3.0835 Validation Accuracy: 48.5419
#
# Time taken for the epoch 11.1138
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.7931
# Batch 100 Loss 0.7337
# Batch 200 Loss 0.6993
# Batch 300 Loss 0.7240
#
# Validating ...
#
# Train Loss: 0.7406 Train Accuracy: 77.3654 Validation Loss: 3.2657 Validation Accuracy: 46.6802
#
# Time taken for the epoch 11.1788
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.6986
# Batch 100 Loss 0.7016
# Batch 200 Loss 0.6964
# Batch 300 Loss 0.7177
#
# Validating ...
#
# Train Loss: 0.7147 Train Accuracy: 77.9595 Validation Loss: 3.3235 Validation Accuracy: 46.4303
#
# Time taken for the epoch 10.9446
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.6861
# Batch 100 Loss 0.6834
# Batch 200 Loss 0.6859
# Batch 300 Loss 0.6786
#
# Validating ...
#
# Train Loss: 0.6907 Train Accuracy: 78.4715 Validation Loss: 3.4448 Validation Accuracy: 46.1534
#
# Time taken for the epoch 11.1134
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.6633
# Batch 100 Loss 0.6680
# Batch 200 Loss 0.6206
# Batch 300 Loss 0.6677
#
# Validating ...
#
# Train Loss: 0.6660 Train Accuracy: 79.2258 Validation Loss: 3.3008 Validation Accuracy: 48.2384
#
# Time taken for the epoch 11.0616
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.6527
# Batch 100 Loss 0.6054
# Batch 200 Loss 0.6601
# Batch 300 Loss 0.6350
#
# Validating ...
#
# Train Loss: 0.6393 Train Accuracy: 79.9429 Validation Loss: 3.5368 Validation Accuracy: 47.5052
#
# Time taken for the epoch 11.1942
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.6140
# Batch 100 Loss 0.6207
# Batch 200 Loss 0.5838
# Batch 300 Loss 0.6449
#
# Validating ...
#
# Train Loss: 0.6077 Train Accuracy: 80.8567 Validation Loss: 3.3440 Validation Accuracy: 49.9848
#
# Time taken for the epoch 11.0939
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.6041
# Batch 100 Loss 0.6005
# Batch 200 Loss 0.5670
# Batch 300 Loss 0.5866
#
# Validating ...
#
# Train Loss: 0.5798 Train Accuracy: 81.7276 Validation Loss: 3.3193 Validation Accuracy: 51.4715
#
# Time taken for the epoch 10.9288
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.5788
# Batch 100 Loss 0.5617
# Batch 200 Loss 0.5243
# Batch 300 Loss 0.6022
#
# Validating ...
#
# Train Loss: 0.5557 Train Accuracy: 82.5121 Validation Loss: 3.1257 Validation Accuracy: 53.6104
#
# Time taken for the epoch 11.2081
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.5109
# Batch 100 Loss 0.5462
# Batch 200 Loss 0.5364
# Batch 300 Loss 0.5570
#
# Validating ...
#
# Train Loss: 0.5347 Train Accuracy: 83.1217 Validation Loss: 3.1375 Validation Accuracy: 54.3848
#
# Time taken for the epoch 11.0586
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.5493
# Batch 100 Loss 0.5496
# Batch 200 Loss 0.4764
# Batch 300 Loss 0.5014
#
# Validating ...
#
# Train Loss: 0.5135 Train Accuracy: 83.7154 Validation Loss: 3.2393 Validation Accuracy: 54.6771
#
# Time taken for the epoch 11.0118
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.4776
# Batch 100 Loss 0.4708
# Batch 200 Loss 0.4329
# Batch 300 Loss 0.4706
#
# Validating ...
#
# Train Loss: 0.4903 Train Accuracy: 84.4341 Validation Loss: 3.0535 Validation Accuracy: 56.8371
#
# Time taken for the epoch 10.9794
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.5052
# Batch 100 Loss 0.4891
# Batch 200 Loss 0.4407
# Batch 300 Loss 0.4409
#
# Validating ...
#
# Train Loss: 0.4689 Train Accuracy: 85.0532 Validation Loss: 3.0112 Validation Accuracy: 57.4731
#
# Time taken for the epoch 11.0629
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.4538
# Batch 100 Loss 0.4558
# Batch 200 Loss 0.4551
# Batch 300 Loss 0.4631
#
# Validating ...
#
# Train Loss: 0.4502 Train Accuracy: 85.7033 Validation Loss: 2.9356 Validation Accuracy: 58.9751
#
# Time taken for the epoch 11.0373
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.4459
# Batch 100 Loss 0.4200
# Batch 200 Loss 0.4114
# Batch 300 Loss 0.4241
#
# Validating ...
#
# Train Loss: 0.4288 Train Accuracy: 86.3270 Validation Loss: 2.9166 Validation Accuracy: 59.5109
#
# Time taken for the epoch 11.0788
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
#
# Training ...
#
# Batch 1 Loss 0.3916
# Batch 100 Loss 0.3719
# Batch 200 Loss 0.3962
# Batch 300 Loss 0.3328
#
# Validating ...
#
# Train Loss: 0.3938 Train Accuracy: 87.2902 Validation Loss: 2.3663 Validation Accuracy: 62.0656
#
# Time taken for the epoch 28.8973
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.3817
# Batch 100 Loss 0.3409
# Batch 200 Loss 0.3905
# Batch 300 Loss 0.3622
#
# Validating ...
#
# Train Loss: 0.3539 Train Accuracy: 88.5047 Validation Loss: 2.3209 Validation Accuracy: 63.6345
#
# Time taken for the epoch 29.0199
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.3281
# Batch 100 Loss 0.3080
# Batch 200 Loss 0.2891
# Batch 300 Loss 0.3020
#
# Validating ...
#
# Train Loss: 0.3128 Train Accuracy: 89.7373 Validation Loss: 2.0738 Validation Accuracy: 67.3110
#
# Time taken for the epoch 28.9030
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.3116
# Batch 100 Loss 0.2582
# Batch 200 Loss 0.2872
# Batch 300 Loss 0.2959
#
# Validating ...
#
# Train Loss: 0.2787 Train Accuracy: 90.7819 Validation Loss: 2.1303 Validation Accuracy: 67.5298
#
# Time taken for the epoch 28.9885
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2709
# Batch 100 Loss 0.2017
# Batch 200 Loss 0.2422
# Batch 300 Loss 0.2385
#
# Validating ...
#
# Train Loss: 0.2501 Train Accuracy: 91.7077 Validation Loss: 2.0130 Validation Accuracy: 69.9210
#
# Time taken for the epoch 28.8188
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2226
# Batch 100 Loss 0.2110
# Batch 200 Loss 0.2091
# Batch 300 Loss 0.2351
#
# Validating ...
#
# Train Loss: 0.2285 Train Accuracy: 92.4633 Validation Loss: 1.7864 Validation Accuracy: 73.0678
#
# Time taken for the epoch 29.2990
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.1965
# Batch 100 Loss 0.2115
# Batch 200 Loss 0.2069
# Batch 300 Loss 0.1821
#
# Validating ...
#
# Train Loss: 0.2113 Train Accuracy: 93.0889 Validation Loss: 1.7828 Validation Accuracy: 73.5801
#
# Time taken for the epoch 28.8538
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.1789
# Batch 100 Loss 0.1839
# Batch 200 Loss 0.2135
# Batch 300 Loss 0.2236
#
# Validating ...
#
# Train Loss: 0.1940 Train Accuracy: 93.6304 Validation Loss: 1.8549 Validation Accuracy: 73.1729
#
# Time taken for the epoch 28.9800
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1731
# Batch 100 Loss 0.1902
# Batch 200 Loss 0.1817
# Batch 300 Loss 0.1551
#
# Validating ...
#
# Train Loss: 0.1821 Train Accuracy: 93.9765 Validation Loss: 1.8482 Validation Accuracy: 74.3401
#
# Time taken for the epoch 28.8952
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1564
# Batch 100 Loss 0.1236
# Batch 200 Loss 0.1864
# Batch 300 Loss 0.1707
#
# Validating ...
#
# Train Loss: 0.1702 Train Accuracy: 94.4504 Validation Loss: 1.8908 Validation Accuracy: 73.9785
#
# Time taken for the epoch 28.8606
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1748
# Batch 100 Loss 0.1330
# Batch 200 Loss 0.1344
# Batch 300 Loss 0.1989
#
# Validating ...
#
# Train Loss: 0.1594 Train Accuracy: 94.7562 Validation Loss: 1.6914 Validation Accuracy: 76.2773
#
# Time taken for the epoch 28.9343
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1378
# Batch 100 Loss 0.1465
# Batch 200 Loss 0.1436
# Batch 300 Loss 0.1466
#
# Validating ...
#
# Train Loss: 0.1507 Train Accuracy: 95.0907 Validation Loss: 1.6620 Validation Accuracy: 77.2341
#
# Time taken for the epoch 28.9349
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▄▄▅▅▆▆▆▇▇▇▇██████</td></tr><tr><td>train loss</td><td>█▆▅▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▁▁▃▃▃▄▄▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>val loss</td><td>▄▆█▅▆▆▅▅▄▄▃▃▃▂▂▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>95.09074</td></tr><tr><td>train loss</td><td>0.15074</td></tr><tr><td>training time</td><td>28.93486</td></tr><tr><td>val acc</td><td>77.23409</td></tr><tr><td>val loss</td><td>1.66196</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">chocolate-sweep-26</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/0lkdt324" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/0lkdt324</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_190552-0lkdt324/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: v4epzckc with config:
# wandb: 	enc_dec_layers: 3
# wandb: 	layer_type: lstm
# wandb: 	units: 256
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220514_191728-v4epzckc</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/v4epzckc" target="_blank">electric-sweep-27</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/l64qp4dv</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9905
# Batch 100 Loss 1.1456
# Batch 200 Loss 1.0155
# Batch 300 Loss 0.9185
#
# Validating ...
#
# Train Loss: 1.1417 Train Accuracy: 66.2528 Validation Loss: 2.6774 Validation Accuracy: 47.4621
#
# Time taken for the epoch 118.1029
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9485
# Batch 100 Loss 0.9184
# Batch 200 Loss 0.8157
# Batch 300 Loss 0.7488
#
# Validating ...
#
# Train Loss: 0.8504 Train Accuracy: 74.2592 Validation Loss: 3.4207 Validation Accuracy: 42.8704
#
# Time taken for the epoch 29.4493
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8342
# Batch 100 Loss 0.8083
# Batch 200 Loss 0.6953
# Batch 300 Loss 0.6319
#
# Validating ...
#
# Train Loss: 0.7101 Train Accuracy: 77.1758 Validation Loss: 2.7635 Validation Accuracy: 52.6107
#
# Time taken for the epoch 29.4542
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.6177
# Batch 100 Loss 0.6114
# Batch 200 Loss 0.6022
# Batch 300 Loss 0.4976
#
# Validating ...
#
# Train Loss: 0.5721 Train Accuracy: 81.0209 Validation Loss: 2.6718 Validation Accuracy: 55.9117
#
# Time taken for the epoch 29.5335
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.5286
# Batch 100 Loss 0.5131
# Batch 200 Loss 0.4682
# Batch 300 Loss 0.4101
#
# Validating ...
#
# Train Loss: 0.4584 Train Accuracy: 84.5011 Validation Loss: 2.4173 Validation Accuracy: 61.2509
#
# Time taken for the epoch 29.6364
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.3767
# Batch 100 Loss 0.3976
# Batch 200 Loss 0.3536
# Batch 300 Loss 0.3663
#
# Validating ...
#
# Train Loss: 0.3614 Train Accuracy: 87.8077 Validation Loss: 2.4095 Validation Accuracy: 63.1629
#
# Time taken for the epoch 29.6307
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.3038
# Batch 100 Loss 0.3249
# Batch 200 Loss 0.2936
# Batch 300 Loss 0.2624
#
# Validating ...
#
# Train Loss: 0.2835 Train Accuracy: 90.2719 Validation Loss: 2.1705 Validation Accuracy: 67.3079
#
# Time taken for the epoch 29.5927
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.2199
# Batch 100 Loss 0.2233
# Batch 200 Loss 0.2205
# Batch 300 Loss 0.2262
#
# Validating ...
#
# Train Loss: 0.2304 Train Accuracy: 92.1480 Validation Loss: 2.0524 Validation Accuracy: 70.1314
#
# Time taken for the epoch 29.5076
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.1976
# Batch 100 Loss 0.2029
# Batch 200 Loss 0.1995
# Batch 300 Loss 0.1809
#
# Validating ...
#
# Train Loss: 0.1914 Train Accuracy: 93.6310 Validation Loss: 1.9726 Validation Accuracy: 72.3569
#
# Time taken for the epoch 29.4381
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.1524
# Batch 100 Loss 0.1494
# Batch 200 Loss 0.1627
# Batch 300 Loss 0.1726
#
# Validating ...
#
# Train Loss: 0.1626 Train Accuracy: 94.7000 Validation Loss: 1.6033 Validation Accuracy: 77.5769
#
# Time taken for the epoch 29.5564
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.1413
# Batch 100 Loss 0.1409
# Batch 200 Loss 0.1459
# Batch 300 Loss 0.1430
#
# Validating ...
#
# Train Loss: 0.1404 Train Accuracy: 95.4082 Validation Loss: 1.7100 Validation Accuracy: 76.5941
#
# Time taken for the epoch 29.9255
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.1215
# Batch 100 Loss 0.1165
# Batch 200 Loss 0.1322
# Batch 300 Loss 0.1314
#
# Validating ...
#
# Train Loss: 0.1220 Train Accuracy: 96.0321 Validation Loss: 1.6152 Validation Accuracy: 78.5993
#
# Time taken for the epoch 29.5257
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.1170
# Batch 100 Loss 0.1016
# Batch 200 Loss 0.1172
# Batch 300 Loss 0.1065
#
# Validating ...
#
# Train Loss: 0.1070 Train Accuracy: 96.5280 Validation Loss: 1.6768 Validation Accuracy: 78.5958
#
# Time taken for the epoch 29.5730
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.0942
# Batch 100 Loss 0.0790
# Batch 200 Loss 0.0939
# Batch 300 Loss 0.0916
#
# Validating ...
#
# Train Loss: 0.0944 Train Accuracy: 96.9851 Validation Loss: 1.6294 Validation Accuracy: 79.0219
#
# Time taken for the epoch 29.5121
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.0828
# Batch 100 Loss 0.0752
# Batch 200 Loss 0.0975
# Batch 300 Loss 0.0996
#
# Validating ...
#
# Train Loss: 0.0843 Train Accuracy: 97.3172 Validation Loss: 1.6618 Validation Accuracy: 79.8551
#
# Time taken for the epoch 29.3133
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.0724
# Batch 100 Loss 0.0662
# Batch 200 Loss 0.0941
# Batch 300 Loss 0.0820
#
# Validating ...
#
# Train Loss: 0.0741 Train Accuracy: 97.6840 Validation Loss: 1.7375 Validation Accuracy: 79.6298
#
# Time taken for the epoch 29.3724
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.0624
# Batch 100 Loss 0.0738
# Batch 200 Loss 0.0625
# Batch 300 Loss 0.0724
#
# Validating ...
#
# Train Loss: 0.0670 Train Accuracy: 97.9288 Validation Loss: 1.7241 Validation Accuracy: 79.3217
#
# Time taken for the epoch 29.3808
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.0581
# Batch 100 Loss 0.0642
# Batch 200 Loss 0.0551
# Batch 300 Loss 0.0634
#
# Validating ...
#
# Train Loss: 0.0599 Train Accuracy: 98.1301 Validation Loss: 1.7338 Validation Accuracy: 80.5211
#
# Time taken for the epoch 29.2883
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.0408
# Batch 100 Loss 0.0475
# Batch 200 Loss 0.0766
# Batch 300 Loss 0.0521
#
# Validating ...
#
# Train Loss: 0.0553 Train Accuracy: 98.2860 Validation Loss: 1.8088 Validation Accuracy: 79.2565
#
# Time taken for the epoch 29.3685
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.0549
# Batch 100 Loss 0.0584
# Batch 200 Loss 0.0550
# Batch 300 Loss 0.0574
#
# Validating ...
#
# Train Loss: 0.0510 Train Accuracy: 98.3446 Validation Loss: 1.7714 Validation Accuracy: 80.3632
#
# Time taken for the epoch 29.5682
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▄▅▆▆▇▇▇▇▇████████</td></tr><tr><td>train loss</td><td>█▆▅▄▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▂▁▃▃▄▅▆▆▆▇▇█████████</td></tr><tr><td>val loss</td><td>▅█▅▅▄▄▃▃▂▁▁▁▁▁▁▂▁▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>98.34455</td></tr><tr><td>train loss</td><td>0.05104</td></tr><tr><td>training time</td><td>29.56824</td></tr><tr><td>val acc</td><td>80.36323</td></tr><tr><td>val loss</td><td>1.77141</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">electric-sweep-27</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/v4epzckc" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/v4epzckc</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_191728-v4epzckc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %% [markdown]
# #Second sweep

# %%
sweep_config2 = {
  "name": "Sweep 2- Assignment3",
  "method": "grid",
  "parameters": {
        "enc_dec_layers": {
           "values": [2, 3]
        },
        "embedding_dim": {
            "values": [64, 128, 256]
        },
        "dropout": {
            "values": [0.2, 0.3]
        }
    }
}

# %%
sweep_id2 = wandb.sweep(sweep_config2, project="cs6910-assignment3")
# Out:
# Create sweep with ID: p25mgmof
# Sweep URL: https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof

# %%
wandb.agent(sweep_id2, function=lambda: train_with_wandb("hi"))
# Out:
# wandb: Agent Starting Run: 7hnygblg with config:
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 64
# wandb: 	enc_dec_layers: 2
# wandb: Currently logged in as: harshagudivada. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_045112-7hnygblg</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/7hnygblg" target="_blank">feasible-sweep-1</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9933
# Batch 100 Loss 1.1702
# Batch 200 Loss 1.1788
# Batch 300 Loss 0.9235
#
# Validating ...
#
# Train Loss: 1.1972 Train Accuracy: 65.9775 Validation Loss: 2.3918 Validation Accuracy: 48.2350
#
# Time taken for the epoch 200.6497
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9465
# Batch 100 Loss 0.9016
# Batch 200 Loss 0.8876
# Batch 300 Loss 0.8749
#
# Validating ...
#
# Train Loss: 0.9144 Train Accuracy: 73.3141 Validation Loss: 2.2572 Validation Accuracy: 51.4902
#
# Time taken for the epoch 115.5331
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8992
# Batch 100 Loss 0.8472
# Batch 200 Loss 0.8525
# Batch 300 Loss 0.8062
#
# Validating ...
#
# Train Loss: 0.8476 Train Accuracy: 74.7927 Validation Loss: 2.7966 Validation Accuracy: 47.2730
#
# Time taken for the epoch 115.7888
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8833
# Batch 100 Loss 0.8027
# Batch 200 Loss 0.7724
# Batch 300 Loss 0.7700
#
# Validating ...
#
# Train Loss: 0.7824 Train Accuracy: 76.2051 Validation Loss: 2.6321 Validation Accuracy: 49.9913
#
# Time taken for the epoch 115.9538
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.7564
# Batch 100 Loss 0.7189
# Batch 200 Loss 0.7356
# Batch 300 Loss 0.7395
#
# Validating ...
#
# Train Loss: 0.7169 Train Accuracy: 77.7206 Validation Loss: 2.6481 Validation Accuracy: 51.1104
#
# Time taken for the epoch 117.6245
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.6900
# Batch 100 Loss 0.6745
# Batch 200 Loss 0.6239
# Batch 300 Loss 0.6043
#
# Validating ...
#
# Train Loss: 0.6497 Train Accuracy: 79.6144 Validation Loss: 2.6460 Validation Accuracy: 52.1743
#
# Time taken for the epoch 117.1360
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.6102
# Batch 100 Loss 0.5514
# Batch 200 Loss 0.5522
# Batch 300 Loss 0.5416
#
# Validating ...
#
# Train Loss: 0.5893 Train Accuracy: 81.2002 Validation Loss: 2.6824 Validation Accuracy: 53.5808
#
# Time taken for the epoch 116.1485
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.5712
# Batch 100 Loss 0.5446
# Batch 200 Loss 0.5266
# Batch 300 Loss 0.4538
#
# Validating ...
#
# Train Loss: 0.5231 Train Accuracy: 83.1015 Validation Loss: 2.5970 Validation Accuracy: 56.3262
#
# Time taken for the epoch 115.4063
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.5165
# Batch 100 Loss 0.4480
# Batch 200 Loss 0.4369
# Batch 300 Loss 0.4355
#
# Validating ...
#
# Train Loss: 0.4559 Train Accuracy: 85.0944 Validation Loss: 2.2807 Validation Accuracy: 60.9382
#
# Time taken for the epoch 115.0829
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.4241
# Batch 100 Loss 0.4057
# Batch 200 Loss 0.3861
# Batch 300 Loss 0.3329
#
# Validating ...
#
# Train Loss: 0.3929 Train Accuracy: 87.1386 Validation Loss: 2.4660 Validation Accuracy: 60.0105
#
# Time taken for the epoch 115.5263
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.3438
# Batch 100 Loss 0.3558
# Batch 200 Loss 0.3382
# Batch 300 Loss 0.2846
#
# Validating ...
#
# Train Loss: 0.3419 Train Accuracy: 88.7264 Validation Loss: 2.3652 Validation Accuracy: 61.7131
#
# Time taken for the epoch 115.5260
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2869
# Batch 100 Loss 0.2785
# Batch 200 Loss 0.2894
# Batch 300 Loss 0.3326
#
# Validating ...
#
# Train Loss: 0.3019 Train Accuracy: 90.0667 Validation Loss: 2.2284 Validation Accuracy: 65.0732
#
# Time taken for the epoch 115.4418
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2923
# Batch 100 Loss 0.2999
# Batch 200 Loss 0.2758
# Batch 300 Loss 0.3019
#
# Validating ...
#
# Train Loss: 0.2716 Train Accuracy: 91.0316 Validation Loss: 1.9980 Validation Accuracy: 67.7909
#
# Time taken for the epoch 115.1515
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2586
# Batch 100 Loss 0.2416
# Batch 200 Loss 0.2028
# Batch 300 Loss 0.2398
#
# Validating ...
#
# Train Loss: 0.2464 Train Accuracy: 91.8144 Validation Loss: 2.1010 Validation Accuracy: 67.3352
#
# Time taken for the epoch 115.3871
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.2257
# Batch 100 Loss 0.2164
# Batch 200 Loss 0.2029
# Batch 300 Loss 0.2318
#
# Validating ...
#
# Train Loss: 0.2281 Train Accuracy: 92.4577 Validation Loss: 1.8942 Validation Accuracy: 71.8406
#
# Time taken for the epoch 115.3214
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.2054
# Batch 100 Loss 0.2019
# Batch 200 Loss 0.2251
# Batch 300 Loss 0.2251
#
# Validating ...
#
# Train Loss: 0.2113 Train Accuracy: 93.1222 Validation Loss: 1.8389 Validation Accuracy: 72.4027
#
# Time taken for the epoch 115.6330
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1889
# Batch 100 Loss 0.2154
# Batch 200 Loss 0.1670
# Batch 300 Loss 0.1881
#
# Validating ...
#
# Train Loss: 0.1975 Train Accuracy: 93.5095 Validation Loss: 1.7701 Validation Accuracy: 73.7756
#
# Time taken for the epoch 115.5177
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1751
# Batch 100 Loss 0.1876
# Batch 200 Loss 0.1951
# Batch 300 Loss 0.1625
#
# Validating ...
#
# Train Loss: 0.1855 Train Accuracy: 93.9487 Validation Loss: 1.6932 Validation Accuracy: 76.0962
#
# Time taken for the epoch 114.8217
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1684
# Batch 100 Loss 0.1745
# Batch 200 Loss 0.1763
# Batch 300 Loss 0.1605
#
# Validating ...
#
# Train Loss: 0.1742 Train Accuracy: 94.2577 Validation Loss: 1.7437 Validation Accuracy: 75.3531
#
# Time taken for the epoch 114.6447
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1483
# Batch 100 Loss 0.1676
# Batch 200 Loss 0.1400
# Batch 300 Loss 0.1880
#
# Validating ...
#
# Train Loss: 0.1648 Train Accuracy: 94.6208 Validation Loss: 1.6410 Validation Accuracy: 76.6429
#
# Time taken for the epoch 114.2214
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▃▄▄▅▅▆▆▇▇▇▇▇█████</td></tr><tr><td>train loss</td><td>█▆▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▂▁▂▂▂▃▃▄▄▄▅▆▆▇▇▇███</td></tr><tr><td>val loss</td><td>▆▅█▇▇▇▇▇▅▆▅▅▃▄▃▂▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>94.62084</td></tr><tr><td>train loss</td><td>0.16484</td></tr><tr><td>training time</td><td>114.22137</td></tr><tr><td>val acc</td><td>76.64292</td></tr><tr><td>val loss</td><td>1.64102</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">feasible-sweep-1</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/7hnygblg" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/7hnygblg</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_045112-7hnygblg/logs</code>
# wandb: Agent Starting Run: zvirp5si with config:
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 64
# wandb: 	enc_dec_layers: 3
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_053132-zvirp5si</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/zvirp5si" target="_blank">sage-sweep-2</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9898
# Batch 100 Loss 1.2218
# Batch 200 Loss 1.1181
# Batch 300 Loss 1.0975
#
# Validating ...
#
# Train Loss: 1.2713 Train Accuracy: 64.4884 Validation Loss: 2.5254 Validation Accuracy: 42.7320
#
# Time taken for the epoch 298.4471
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 1.0666
# Batch 100 Loss 1.0023
# Batch 200 Loss 0.9493
# Batch 300 Loss 0.8662
#
# Validating ...
#
# Train Loss: 0.9667 Train Accuracy: 72.7097 Validation Loss: 3.1002 Validation Accuracy: 41.8566
#
# Time taken for the epoch 177.4797
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.9235
# Batch 100 Loss 0.8931
# Batch 200 Loss 0.9026
# Batch 300 Loss 0.8374
#
# Validating ...
#
# Train Loss: 0.8936 Train Accuracy: 73.8756 Validation Loss: 2.4189 Validation Accuracy: 51.7210
#
# Time taken for the epoch 177.4398
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8892
# Batch 100 Loss 0.8636
# Batch 200 Loss 0.8415
# Batch 300 Loss 0.7907
#
# Validating ...
#
# Train Loss: 0.8433 Train Accuracy: 74.8166 Validation Loss: 2.5871 Validation Accuracy: 50.7680
#
# Time taken for the epoch 178.1215
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.8044
# Batch 100 Loss 0.7831
# Batch 200 Loss 0.7370
# Batch 300 Loss 0.7171
#
# Validating ...
#
# Train Loss: 0.7615 Train Accuracy: 76.7749 Validation Loss: 2.8654 Validation Accuracy: 49.3878
#
# Time taken for the epoch 178.0258
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.7069
# Batch 100 Loss 0.6515
# Batch 200 Loss 0.6843
# Batch 300 Loss 0.6583
#
# Validating ...
#
# Train Loss: 0.6669 Train Accuracy: 78.9425 Validation Loss: 2.5741 Validation Accuracy: 53.7986
#
# Time taken for the epoch 178.0126
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.6374
# Batch 100 Loss 0.6179
# Batch 200 Loss 0.6347
# Batch 300 Loss 0.5517
#
# Validating ...
#
# Train Loss: 0.5873 Train Accuracy: 81.3242 Validation Loss: 2.4584 Validation Accuracy: 56.9055
#
# Time taken for the epoch 177.8353
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.5653
# Batch 100 Loss 0.5589
# Batch 200 Loss 0.4912
# Batch 300 Loss 0.4858
#
# Validating ...
#
# Train Loss: 0.5207 Train Accuracy: 83.3429 Validation Loss: 2.5210 Validation Accuracy: 57.7685
#
# Time taken for the epoch 176.8410
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.5040
# Batch 100 Loss 0.4614
# Batch 200 Loss 0.4724
# Batch 300 Loss 0.4305
#
# Validating ...
#
# Train Loss: 0.4629 Train Accuracy: 84.9881 Validation Loss: 2.3584 Validation Accuracy: 60.5591
#
# Time taken for the epoch 176.3147
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.4432
# Batch 100 Loss 0.4350
# Batch 200 Loss 0.4256
# Batch 300 Loss 0.4195
#
# Validating ...
#
# Train Loss: 0.4086 Train Accuracy: 86.5278 Validation Loss: 2.4317 Validation Accuracy: 61.3209
#
# Time taken for the epoch 178.6430
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.3701
# Batch 100 Loss 0.3681
# Batch 200 Loss 0.3476
# Batch 300 Loss 0.3457
#
# Validating ...
#
# Train Loss: 0.3585 Train Accuracy: 88.1677 Validation Loss: 2.2499 Validation Accuracy: 64.9162
#
# Time taken for the epoch 177.5022
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.3125
# Batch 100 Loss 0.2754
# Batch 200 Loss 0.3202
# Batch 300 Loss 0.3191
#
# Validating ...
#
# Train Loss: 0.3193 Train Accuracy: 89.5222 Validation Loss: 1.9913 Validation Accuracy: 69.5890
#
# Time taken for the epoch 177.8994
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2756
# Batch 100 Loss 0.2947
# Batch 200 Loss 0.2838
# Batch 300 Loss 0.2835
#
# Validating ...
#
# Train Loss: 0.2880 Train Accuracy: 90.4459 Validation Loss: 2.0889 Validation Accuracy: 68.6526
#
# Time taken for the epoch 177.6509
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2557
# Batch 100 Loss 0.2802
# Batch 200 Loss 0.2981
# Batch 300 Loss 0.2827
#
# Validating ...
#
# Train Loss: 0.2623 Train Accuracy: 91.2864 Validation Loss: 1.8792 Validation Accuracy: 71.5320
#
# Time taken for the epoch 177.8896
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.2652
# Batch 100 Loss 0.2343
# Batch 200 Loss 0.2781
# Batch 300 Loss 0.2049
#
# Validating ...
#
# Train Loss: 0.2427 Train Accuracy: 91.9495 Validation Loss: 1.8862 Validation Accuracy: 72.9976
#
# Time taken for the epoch 177.0476
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.2332
# Batch 100 Loss 0.2181
# Batch 200 Loss 0.2236
# Batch 300 Loss 0.2342
#
# Validating ...
#
# Train Loss: 0.2235 Train Accuracy: 92.5744 Validation Loss: 1.8519 Validation Accuracy: 73.3783
#
# Time taken for the epoch 177.5220
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.2412
# Batch 100 Loss 0.2024
# Batch 200 Loss 0.2289
# Batch 300 Loss 0.1934
#
# Validating ...
#
# Train Loss: 0.2082 Train Accuracy: 93.1566 Validation Loss: 1.7612 Validation Accuracy: 75.1403
#
# Time taken for the epoch 178.3181
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.2136
# Batch 100 Loss 0.1869
# Batch 200 Loss 0.1980
# Batch 300 Loss 0.1907
#
# Validating ...
#
# Train Loss: 0.1932 Train Accuracy: 93.7435 Validation Loss: 1.7485 Validation Accuracy: 75.5831
#
# Time taken for the epoch 177.7025
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1750
# Batch 100 Loss 0.1867
# Batch 200 Loss 0.1939
# Batch 300 Loss 0.1709
#
# Validating ...
#
# Train Loss: 0.1805 Train Accuracy: 94.0888 Validation Loss: 1.6796 Validation Accuracy: 76.8802
#
# Time taken for the epoch 177.8359
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1644
# Batch 100 Loss 0.1651
# Batch 200 Loss 0.1527
# Batch 300 Loss 0.1536
#
# Validating ...
#
# Train Loss: 0.1701 Train Accuracy: 94.3937 Validation Loss: 1.6996 Validation Accuracy: 76.6899
#
# Time taken for the epoch 178.3295
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▃▄▄▅▅▆▆▇▇▇▇▇█████</td></tr><tr><td>train loss</td><td>█▆▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▁▃▃▃▃▄▄▅▅▆▇▆▇▇▇████</td></tr><tr><td>val loss</td><td>▅█▅▅▇▅▅▅▄▅▄▃▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>94.39365</td></tr><tr><td>train loss</td><td>0.17007</td></tr><tr><td>training time</td><td>178.32952</td></tr><tr><td>val acc</td><td>76.68987</td></tr><tr><td>val loss</td><td>1.69963</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sage-sweep-2</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/zvirp5si" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/zvirp5si</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_053132-zvirp5si/logs</code>
# wandb: Agent Starting Run: pwj0hzif with config:
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 128
# wandb: 	enc_dec_layers: 2
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_063311-pwj0hzif</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/pwj0hzif" target="_blank">noble-sweep-3</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9979
# Batch 100 Loss 1.1365
# Batch 200 Loss 1.0541
# Batch 300 Loss 1.0167
#
# Validating ...
#
# Train Loss: 1.1860 Train Accuracy: 66.6643 Validation Loss: 2.1628 Validation Accuracy: 53.8665
#
# Time taken for the epoch 214.1721
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9656
# Batch 100 Loss 0.9245
# Batch 200 Loss 0.8662
# Batch 300 Loss 0.8135
#
# Validating ...
#
# Train Loss: 0.9083 Train Accuracy: 72.9589 Validation Loss: 2.2344 Validation Accuracy: 52.0920
#
# Time taken for the epoch 127.2420
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8084
# Batch 100 Loss 0.7925
# Batch 200 Loss 0.7456
# Batch 300 Loss 0.6564
#
# Validating ...
#
# Train Loss: 0.7443 Train Accuracy: 77.0290 Validation Loss: 2.3864 Validation Accuracy: 52.8533
#
# Time taken for the epoch 127.1857
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.7113
# Batch 100 Loss 0.6727
# Batch 200 Loss 0.6640
# Batch 300 Loss 0.6067
#
# Validating ...
#
# Train Loss: 0.6403 Train Accuracy: 79.8540 Validation Loss: 2.1456 Validation Accuracy: 58.1647
#
# Time taken for the epoch 126.7562
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.5804
# Batch 100 Loss 0.5634
# Batch 200 Loss 0.4951
# Batch 300 Loss 0.5376
#
# Validating ...
#
# Train Loss: 0.5371 Train Accuracy: 82.6057 Validation Loss: 2.0252 Validation Accuracy: 61.6632
#
# Time taken for the epoch 145.1952
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.4960
# Batch 100 Loss 0.4855
# Batch 200 Loss 0.4112
# Batch 300 Loss 0.3978
#
# Validating ...
#
# Train Loss: 0.4463 Train Accuracy: 85.2362 Validation Loss: 1.8232 Validation Accuracy: 66.4969
#
# Time taken for the epoch 126.8164
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.4079
# Batch 100 Loss 0.3791
# Batch 200 Loss 0.3502
# Batch 300 Loss 0.3198
#
# Validating ...
#
# Train Loss: 0.3687 Train Accuracy: 87.6626 Validation Loss: 1.6761 Validation Accuracy: 70.4408
#
# Time taken for the epoch 126.5716
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.3321
# Batch 100 Loss 0.3213
# Batch 200 Loss 0.3161
# Batch 300 Loss 0.2987
#
# Validating ...
#
# Train Loss: 0.3131 Train Accuracy: 89.5220 Validation Loss: 1.6311 Validation Accuracy: 71.9480
#
# Time taken for the epoch 126.5531
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.2857
# Batch 100 Loss 0.2895
# Batch 200 Loss 0.2729
# Batch 300 Loss 0.2644
#
# Validating ...
#
# Train Loss: 0.2759 Train Accuracy: 90.8911 Validation Loss: 1.5612 Validation Accuracy: 73.6291
#
# Time taken for the epoch 126.9530
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.2325
# Batch 100 Loss 0.2970
# Batch 200 Loss 0.2715
# Batch 300 Loss 0.2375
#
# Validating ...
#
# Train Loss: 0.2466 Train Accuracy: 91.8291 Validation Loss: 1.4835 Validation Accuracy: 76.4188
#
# Time taken for the epoch 127.3694
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.2545
# Batch 100 Loss 0.2349
# Batch 200 Loss 0.2456
# Batch 300 Loss 0.2321
#
# Validating ...
#
# Train Loss: 0.2248 Train Accuracy: 92.5908 Validation Loss: 1.4769 Validation Accuracy: 77.3223
#
# Time taken for the epoch 127.1581
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2399
# Batch 100 Loss 0.2057
# Batch 200 Loss 0.1931
# Batch 300 Loss 0.2222
#
# Validating ...
#
# Train Loss: 0.2075 Train Accuracy: 93.2002 Validation Loss: 1.4717 Validation Accuracy: 77.5859
#
# Time taken for the epoch 127.1895
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.1738
# Batch 100 Loss 0.2011
# Batch 200 Loss 0.1875
# Batch 300 Loss 0.1885
#
# Validating ...
#
# Train Loss: 0.1920 Train Accuracy: 93.7045 Validation Loss: 1.4417 Validation Accuracy: 78.3101
#
# Time taken for the epoch 127.6667
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2046
# Batch 100 Loss 0.1618
# Batch 200 Loss 0.1971
# Batch 300 Loss 0.1463
#
# Validating ...
#
# Train Loss: 0.1782 Train Accuracy: 94.1967 Validation Loss: 1.4245 Validation Accuracy: 79.3083
#
# Time taken for the epoch 127.2901
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.1631
# Batch 100 Loss 0.1728
# Batch 200 Loss 0.1903
# Batch 300 Loss 0.1584
#
# Validating ...
#
# Train Loss: 0.1666 Train Accuracy: 94.6159 Validation Loss: 1.4628 Validation Accuracy: 79.0089
#
# Time taken for the epoch 127.2804
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.1684
# Batch 100 Loss 0.1469
# Batch 200 Loss 0.1406
# Batch 300 Loss 0.1783
#
# Validating ...
#
# Train Loss: 0.1563 Train Accuracy: 94.9321 Validation Loss: 1.4643 Validation Accuracy: 80.0487
#
# Time taken for the epoch 126.6345
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1530
# Batch 100 Loss 0.1339
# Batch 200 Loss 0.1626
# Batch 300 Loss 0.1255
#
# Validating ...
#
# Train Loss: 0.1477 Train Accuracy: 95.2086 Validation Loss: 1.4488 Validation Accuracy: 80.3465
#
# Time taken for the epoch 127.3073
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1466
# Batch 100 Loss 0.1403
# Batch 200 Loss 0.1397
# Batch 300 Loss 0.1340
#
# Validating ...
#
# Train Loss: 0.1395 Train Accuracy: 95.4412 Validation Loss: 1.4529 Validation Accuracy: 80.3871
#
# Time taken for the epoch 127.2372
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1390
# Batch 100 Loss 0.1322
# Batch 200 Loss 0.1385
# Batch 300 Loss 0.1487
#
# Validating ...
#
# Train Loss: 0.1318 Train Accuracy: 95.7273 Validation Loss: 1.4895 Validation Accuracy: 79.5614
#
# Time taken for the epoch 127.1959
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1044
# Batch 100 Loss 0.1348
# Batch 200 Loss 0.1407
# Batch 300 Loss 0.1180
#
# Validating ...
#
# Train Loss: 0.1248 Train Accuracy: 95.9731 Validation Loss: 1.4693 Validation Accuracy: 80.8823
#
# Time taken for the epoch 127.5805
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▄▅▅▆▆▇▇▇▇▇███████</td></tr><tr><td>train loss</td><td>█▆▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▁▁▂▃▅▅▆▆▇▇▇▇███████</td></tr><tr><td>val loss</td><td>▆▇█▆▅▄▃▃▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>95.97314</td></tr><tr><td>train loss</td><td>0.12479</td></tr><tr><td>training time</td><td>127.5805</td></tr><tr><td>val acc</td><td>80.88235</td></tr><tr><td>val loss</td><td>1.46934</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">noble-sweep-3</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/pwj0hzif" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/pwj0hzif</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_063311-pwj0hzif/logs</code>
# wandb: Agent Starting Run: vbmqlct4 with config:
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 128
# wandb: 	enc_dec_layers: 3
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_071745-vbmqlct4</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/vbmqlct4" target="_blank">northern-sweep-4</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9939
# Batch 100 Loss 1.1613
# Batch 200 Loss 1.0818
# Batch 300 Loss 0.9579
#
# Validating ...
#
# Train Loss: 1.1887 Train Accuracy: 66.0006 Validation Loss: 2.4379 Validation Accuracy: 47.0890
#
# Time taken for the epoch 314.4798
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9280
# Batch 100 Loss 0.9340
# Batch 200 Loss 0.8978
# Batch 300 Loss 0.8606
#
# Validating ...
#
# Train Loss: 0.9070 Train Accuracy: 73.5235 Validation Loss: 2.4667 Validation Accuracy: 51.0682
#
# Time taken for the epoch 189.8879
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8829
# Batch 100 Loss 0.8403
# Batch 200 Loss 0.8077
# Batch 300 Loss 0.7856
#
# Validating ...
#
# Train Loss: 0.8308 Train Accuracy: 75.2538 Validation Loss: 2.5557 Validation Accuracy: 51.0399
#
# Time taken for the epoch 190.5496
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.8073
# Batch 100 Loss 0.7562
# Batch 200 Loss 0.7103
# Batch 300 Loss 0.7241
#
# Validating ...
#
# Train Loss: 0.7255 Train Accuracy: 77.5177 Validation Loss: 2.6320 Validation Accuracy: 51.8131
#
# Time taken for the epoch 190.8271
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.6827
# Batch 100 Loss 0.6393
# Batch 200 Loss 0.6171
# Batch 300 Loss 0.6170
#
# Validating ...
#
# Train Loss: 0.6353 Train Accuracy: 79.9265 Validation Loss: 2.8617 Validation Accuracy: 51.6395
#
# Time taken for the epoch 191.4560
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.6093
# Batch 100 Loss 0.5515
# Batch 200 Loss 0.5343
# Batch 300 Loss 0.5316
#
# Validating ...
#
# Train Loss: 0.5512 Train Accuracy: 82.2243 Validation Loss: 2.5137 Validation Accuracy: 56.7211
#
# Time taken for the epoch 192.0317
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.4969
# Batch 100 Loss 0.4328
# Batch 200 Loss 0.4747
# Batch 300 Loss 0.4397
#
# Validating ...
#
# Train Loss: 0.4689 Train Accuracy: 84.8363 Validation Loss: 2.4066 Validation Accuracy: 60.1171
#
# Time taken for the epoch 192.3272
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.4328
# Batch 100 Loss 0.4273
# Batch 200 Loss 0.4340
# Batch 300 Loss 0.4076
#
# Validating ...
#
# Train Loss: 0.3982 Train Accuracy: 86.9960 Validation Loss: 2.3405 Validation Accuracy: 61.5805
#
# Time taken for the epoch 192.6577
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.3834
# Batch 100 Loss 0.3604
# Batch 200 Loss 0.3594
# Batch 300 Loss 0.3079
#
# Validating ...
#
# Train Loss: 0.3421 Train Accuracy: 88.7497 Validation Loss: 2.2637 Validation Accuracy: 64.1723
#
# Time taken for the epoch 191.8351
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.3381
# Batch 100 Loss 0.3205
# Batch 200 Loss 0.2714
# Batch 300 Loss 0.2486
#
# Validating ...
#
# Train Loss: 0.2933 Train Accuracy: 90.3661 Validation Loss: 2.2191 Validation Accuracy: 66.2688
#
# Time taken for the epoch 191.4145
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.2609
# Batch 100 Loss 0.2583
# Batch 200 Loss 0.2265
# Batch 300 Loss 0.2758
#
# Validating ...
#
# Train Loss: 0.2558 Train Accuracy: 91.5275 Validation Loss: 2.1577 Validation Accuracy: 67.4076
#
# Time taken for the epoch 192.0782
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2294
# Batch 100 Loss 0.2432
# Batch 200 Loss 0.2157
# Batch 300 Loss 0.2227
#
# Validating ...
#
# Train Loss: 0.2269 Train Accuracy: 92.5116 Validation Loss: 1.8942 Validation Accuracy: 70.9812
#
# Time taken for the epoch 192.5994
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2114
# Batch 100 Loss 0.1916
# Batch 200 Loss 0.2008
# Batch 300 Loss 0.2105
#
# Validating ...
#
# Train Loss: 0.2057 Train Accuracy: 93.2143 Validation Loss: 1.9441 Validation Accuracy: 71.2318
#
# Time taken for the epoch 192.5520
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.1548
# Batch 100 Loss 0.1790
# Batch 200 Loss 0.2006
# Batch 300 Loss 0.1601
#
# Validating ...
#
# Train Loss: 0.1876 Train Accuracy: 93.8811 Validation Loss: 1.7665 Validation Accuracy: 74.4341
#
# Time taken for the epoch 193.8144
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.1740
# Batch 100 Loss 0.1512
# Batch 200 Loss 0.1698
# Batch 300 Loss 0.1817
#
# Validating ...
#
# Train Loss: 0.1734 Train Accuracy: 94.3566 Validation Loss: 1.7679 Validation Accuracy: 74.8473
#
# Time taken for the epoch 197.3332
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.1402
# Batch 100 Loss 0.1729
# Batch 200 Loss 0.1810
# Batch 300 Loss 0.1937
#
# Validating ...
#
# Train Loss: 0.1602 Train Accuracy: 94.8083 Validation Loss: 1.6501 Validation Accuracy: 76.6447
#
# Time taken for the epoch 194.4977
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1645
# Batch 100 Loss 0.1379
# Batch 200 Loss 0.1596
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# Batch 300 Loss 0.1479
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# Validating ...
#
# Train Loss: 0.1485 Train Accuracy: 95.0667 Validation Loss: 1.5550 Validation Accuracy: 79.1095
#
# Time taken for the epoch 192.3135
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1296
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# wandb: Network error (HTTPError), entering retry loop.
# Batch 100 Loss 0.1221
# Batch 200 Loss 0.1317
# Batch 300 Loss 0.1109
#
# Validating ...
#
# Train Loss: 0.1389 Train Accuracy: 95.4233 Validation Loss: 1.7207 Validation Accuracy: 77.2140
#
# Time taken for the epoch 191.9324
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1234
# Batch 100 Loss 0.1266
# Batch 200 Loss 0.1325
# Batch 300 Loss 0.1444
#
# Validating ...
#
# Train Loss: 0.1296 Train Accuracy: 95.7888 Validation Loss: 1.5487 Validation Accuracy: 79.4208
#
# Time taken for the epoch 192.3264
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1256
# Batch 100 Loss 0.1284
# Batch 200 Loss 0.1139
# Batch 300 Loss 0.1295
#
# Validating ...
#
# Train Loss: 0.1210 Train Accuracy: 96.0812 Validation Loss: 1.6165 Validation Accuracy: 78.6657
#
# Time taken for the epoch 193.7575
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▄▄▅▅▆▆▇▇▇▇▇██████</td></tr><tr><td>train loss</td><td>█▆▆▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▂▂▂▂▃▄▄▅▅▅▆▆▇▇▇████</td></tr><tr><td>val loss</td><td>▆▆▆▇█▆▆▅▅▅▄▃▃▂▂▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>96.08123</td></tr><tr><td>train loss</td><td>0.121</td></tr><tr><td>training time</td><td>193.75747</td></tr><tr><td>val acc</td><td>78.66566</td></tr><tr><td>val loss</td><td>1.61649</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">northern-sweep-4</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/vbmqlct4" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/vbmqlct4</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_071745-vbmqlct4/logs</code>
# wandb: Agent Starting Run: 0e6jf7j5 with config:
# wandb: 	dropout: 0.2
# wandb: 	embedding_dim: 256
# wandb: 	enc_dec_layers: 2
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_082424-0e6jf7j5</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/0e6jf7j5" target="_blank">deft-sweep-5</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 4.0011
# Batch 100 Loss 1.1307
# Batch 200 Loss 1.0788
# Batch 300 Loss 0.9874
#
# Validating ...
#
# Train Loss: 1.1693 Train Accuracy: 66.7686 Validation Loss: 3.4296 Validation Accuracy: 31.1851
#
# Time taken for the epoch 234.4835
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 1.0132
# Batch 100 Loss 0.9082
# Batch 200 Loss 0.8860
# Batch 300 Loss 0.8641
#
# Validating ...
#
# Train Loss: 0.9044 Train Accuracy: 73.2194 Validation Loss: 2.2672 Validation Accuracy: 52.1571
#
# Time taken for the epoch 146.3885
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8348
# Batch 100 Loss 0.7179
# Batch 200 Loss 0.7016
# Batch 300 Loss 0.6676
#
# Validating ...
#
# Train Loss: 0.7095 Train Accuracy: 77.2322 Validation Loss: 1.9592 Validation Accuracy: 59.6771
#
# Time taken for the epoch 146.1812
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.6022
# Batch 100 Loss 0.5350
# Batch 200 Loss 0.5055
# Batch 300 Loss 0.4744
#
# Validating ...
#
# Train Loss: 0.5322 Train Accuracy: 82.4109 Validation Loss: 1.7494 Validation Accuracy: 64.9281
#
# Time taken for the epoch 157.2118
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.4302
# Batch 100 Loss 0.4254
# Batch 200 Loss 0.3877
# Batch 300 Loss 0.3780
#
# Validating ...
#
# Train Loss: 0.4037 Train Accuracy: 86.4591 Validation Loss: 1.5377 Validation Accuracy: 70.5533
#
# Time taken for the epoch 151.4839
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.3316
# Batch 100 Loss 0.3825
# Batch 200 Loss 0.2820
# Batch 300 Loss 0.2936
#
# Validating ...
#
# Train Loss: 0.3235 Train Accuracy: 89.1035 Validation Loss: 1.4651 Validation Accuracy: 73.6760
#
# Time taken for the epoch 149.4852
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.2856
# Batch 100 Loss 0.2674
# Batch 200 Loss 0.2774
# Batch 300 Loss 0.2684
#
# Validating ...
#
# Train Loss: 0.2764 Train Accuracy: 90.7148 Validation Loss: 1.4158 Validation Accuracy: 76.0740
#
# Time taken for the epoch 149.2858
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.2333
# Batch 100 Loss 0.2650
# Batch 200 Loss 0.2358
# Batch 300 Loss 0.2819
#
# Validating ...
#
# Train Loss: 0.2428 Train Accuracy: 91.9458 Validation Loss: 1.3991 Validation Accuracy: 76.2987
#
# Time taken for the epoch 149.9349
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.2292
# Batch 100 Loss 0.2215
# Batch 200 Loss 0.2116
# Batch 300 Loss 0.2147
#
# Validating ...
#
# Train Loss: 0.2182 Train Accuracy: 92.7896 Validation Loss: 1.4272 Validation Accuracy: 76.7297
#
# Time taken for the epoch 149.8901
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.1801
# Batch 100 Loss 0.1764
# Batch 200 Loss 0.2209
# Batch 300 Loss 0.2004
#
# Validating ...
#
# Train Loss: 0.1972 Train Accuracy: 93.4663 Validation Loss: 1.3695 Validation Accuracy: 78.1081
#
# Time taken for the epoch 151.0609
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.1848
# Batch 100 Loss 0.1975
# Batch 200 Loss 0.1800
# wandb: ERROR Error while calling W&B API: context deadline exceeded (<Response [500]>)
# Batch 300 Loss 0.1773
#
# Validating ...
#
# Train Loss: 0.1815 Train Accuracy: 94.0186 Validation Loss: 1.3289 Validation Accuracy: 79.9524
#
# Time taken for the epoch 151.8802
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.1720
# Batch 100 Loss 0.1757
# Batch 200 Loss 0.1655
# Batch 300 Loss 0.1488
#
# Validating ...
#
# Train Loss: 0.1676 Train Accuracy: 94.4739 Validation Loss: 1.3638 Validation Accuracy: 79.4093
#
# Time taken for the epoch 205.6169
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.1727
# Batch 100 Loss 0.1509
# Batch 200 Loss 0.1446
# Batch 300 Loss 0.1613
#
# Validating ...
#
# Train Loss: 0.1570 Train Accuracy: 94.8261 Validation Loss: 1.3606 Validation Accuracy: 80.2894
#
# Time taken for the epoch 151.5325
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.1368
# Batch 100 Loss 0.1590
# Batch 200 Loss 0.1380
# Batch 300 Loss 0.1651
#
# Validating ...
#
# Train Loss: 0.1469 Train Accuracy: 95.1558 Validation Loss: 1.3398 Validation Accuracy: 80.6980
#
# Time taken for the epoch 153.0445
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.1197
# Batch 100 Loss 0.1295
# Batch 200 Loss 0.1296
# Batch 300 Loss 0.1318
#
# Validating ...
#
# Train Loss: 0.1377 Train Accuracy: 95.5029 Validation Loss: 1.3604 Validation Accuracy: 80.8329
#
# Time taken for the epoch 151.3721
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.1221
# Batch 100 Loss 0.1137
# Batch 200 Loss 0.1255
# Batch 300 Loss 0.1098
#
# Validating ...
#
# Train Loss: 0.1303 Train Accuracy: 95.7372 Validation Loss: 1.4092 Validation Accuracy: 80.7195
#
# Time taken for the epoch 150.8172
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1320
# Batch 100 Loss 0.1210
# Batch 200 Loss 0.1260
# Batch 300 Loss 0.1007
#
# Validating ...
#
# Train Loss: 0.1228 Train Accuracy: 95.9405 Validation Loss: 1.4110 Validation Accuracy: 80.8833
#
# Time taken for the epoch 151.8484
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1025
# Batch 100 Loss 0.1022
# Batch 200 Loss 0.1322
# Batch 300 Loss 0.1411
#
# Validating ...
#
# Train Loss: 0.1168 Train Accuracy: 96.1908 Validation Loss: 1.4177 Validation Accuracy: 81.4023
#
# Time taken for the epoch 149.6936
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.0969
# Batch 100 Loss 0.0974
# Batch 200 Loss 0.1057
# Batch 300 Loss 0.1039
#
# Validating ...
#
# Train Loss: 0.1100 Train Accuracy: 96.4437 Validation Loss: 1.4343 Validation Accuracy: 81.2236
#
# Time taken for the epoch 148.7484
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1175
# Batch 100 Loss 0.1020
# Batch 200 Loss 0.1017
# Batch 300 Loss 0.0883
#
# Validating ...
#
# Train Loss: 0.1048 Train Accuracy: 96.5607 Validation Loss: 1.4632 Validation Accuracy: 80.9797
#
# Time taken for the epoch 167.2548
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# ...
#
# Time taken for the epoch 118.5663
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2514
# Batch 100 Loss 0.2336
# Batch 200 Loss 0.2631
# Batch 300 Loss 0.2213
#
# Validating ...
#
# Train Loss: 0.2373 Train Accuracy: 92.2442 Validation Loss: 1.6325 Validation Accuracy: 75.2692
#
# Time taken for the epoch 118.2922
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2084
# Batch 100 Loss 0.2030
# Batch 200 Loss 0.2403
# Batch 300 Loss 0.2187
#
# Validating ...
#
# Train Loss: 0.2176 Train Accuracy: 92.9683 Validation Loss: 1.5422 Validation Accuracy: 76.0156
#
# Time taken for the epoch 118.6510
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2083
# Batch 100 Loss 0.2066
# Batch 200 Loss 0.2419
# Batch 300 Loss 0.1895
#
# Validating ...
#
# Train Loss: 0.2012 Train Accuracy: 93.4411 Validation Loss: 1.5260 Validation Accuracy: 76.9728
#
# Time taken for the epoch 118.3353
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.1644
# Batch 100 Loss 0.1703
# Batch 200 Loss 0.1766
# Batch 300 Loss 0.1656
#
# Validating ...
#
# Train Loss: 0.1866 Train Accuracy: 93.9967 Validation Loss: 1.5100 Validation Accuracy: 77.9773
#
# Time taken for the epoch 118.4354
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.1782
# Batch 100 Loss 0.2099
# Batch 200 Loss 0.1783
# Batch 300 Loss 0.1829
#
# Validating ...
#
# Train Loss: 0.1751 Train Accuracy: 94.2945 Validation Loss: 1.4903 Validation Accuracy: 78.7175
#
# Time taken for the epoch 118.5121
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1858
# Batch 100 Loss 0.1787
# Batch 200 Loss 0.1815
# Batch 300 Loss 0.1579
#
# Validating ...
#
# Train Loss: 0.1638 Train Accuracy: 94.7296 Validation Loss: 1.4682 Validation Accuracy: 79.3379
#
# Time taken for the epoch 118.5901
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1393
# Batch 100 Loss 0.1495
# Batch 200 Loss 0.1182
# Batch 300 Loss 0.1419
#
# Validating ...
#
# Train Loss: 0.1544 Train Accuracy: 95.0422 Validation Loss: 1.4614 Validation Accuracy: 79.7706
#
# Time taken for the epoch 118.9569
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1350
# Batch 100 Loss 0.1426
# Batch 200 Loss 0.1418
# Batch 300 Loss 0.1471
#
# Validating ...
#
# Train Loss: 0.1454 Train Accuracy: 95.3079 Validation Loss: 1.4521 Validation Accuracy: 80.4241
#
# Time taken for the epoch 119.9651
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1211
# Batch 100 Loss 0.1399
# Batch 200 Loss 0.1301
# Batch 300 Loss 0.1081
#
# Validating ...
#
# Train Loss: 0.1372 Train Accuracy: 95.5577 Validation Loss: 1.4692 Validation Accuracy: 80.2275
#
# Time taken for the epoch 119.0103
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▂▃▄▅▅▆▆▆▇▇▇▇▇██████</td></tr><tr><td>train loss</td><td>█▆▅▅▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▂▁▁▂▂▄▄▅▅▆▇▇▇▇▇█████</td></tr><tr><td>val loss</td><td>█▇▇██▆▅▄▅▃▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>95.55773</td></tr><tr><td>train loss</td><td>0.13722</td></tr><tr><td>training time</td><td>119.01033</td></tr><tr><td>val acc</td><td>80.2275</td></tr><tr><td>val loss</td><td>1.46918</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">likely-sweep-7</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/i8sg8zek" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/i8sg8zek</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_103315-i8sg8zek/logs</code>
# wandb: Agent Starting Run: 79tjvetz with config:
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 64
# wandb: 	enc_dec_layers: 3
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_111446-79tjvetz</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/79tjvetz" target="_blank">dry-sweep-8</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
#
# Batch 1 Loss 3.9892
# Batch 100 Loss 1.1997
# Batch 200 Loss 1.0520
# Batch 300 Loss 1.0204
#
# Validating ...
#
# Train Loss: 1.2087 Train Accuracy: 65.8216 Validation Loss: 3.0124 Validation Accuracy: 38.2768
#
# Time taken for the epoch 305.0879
# ----------------------------------------------------------------------------------------------------
# EPOCH 2
#
# Training ...
#
# Batch 1 Loss 0.9836
# Batch 100 Loss 0.9459
# Batch 200 Loss 0.8918
# Batch 300 Loss 0.8631
#
# Validating ...
#
# Train Loss: 0.9097 Train Accuracy: 73.3048 Validation Loss: 2.8802 Validation Accuracy: 44.8117
#
# Time taken for the epoch 181.2504
# ----------------------------------------------------------------------------------------------------
# EPOCH 3
#
# Training ...
#
# Batch 1 Loss 0.8906
# Batch 100 Loss 0.8441
# Batch 200 Loss 0.7812
# Batch 300 Loss 0.7941
#
# Validating ...
#
# Train Loss: 0.8260 Train Accuracy: 75.1906 Validation Loss: 2.6910 Validation Accuracy: 48.8985
#
# Time taken for the epoch 181.3226
# ----------------------------------------------------------------------------------------------------
# EPOCH 4
#
# Training ...
#
# Batch 1 Loss 0.7617
# Batch 100 Loss 0.7668
# Batch 200 Loss 0.7290
# Batch 300 Loss 0.7282
#
# Validating ...
#
# Train Loss: 0.7337 Train Accuracy: 77.2663 Validation Loss: 2.8919 Validation Accuracy: 48.0088
#
# Time taken for the epoch 181.7403
# ----------------------------------------------------------------------------------------------------
# EPOCH 5
#
# Training ...
#
# Batch 1 Loss 0.6895
# Batch 100 Loss 0.7458
# Batch 200 Loss 0.6317
# Batch 300 Loss 0.6359
#
# Validating ...
#
# Train Loss: 0.6545 Train Accuracy: 79.4198 Validation Loss: 2.9710 Validation Accuracy: 49.9459
#
# Time taken for the epoch 182.0695
# ----------------------------------------------------------------------------------------------------
# EPOCH 6
#
# Training ...
#
# Batch 1 Loss 0.6075
# Batch 100 Loss 0.5892
# Batch 200 Loss 0.5607
# Batch 300 Loss 0.5663
#
# Validating ...
#
# Train Loss: 0.5740 Train Accuracy: 81.6125 Validation Loss: 2.6216 Validation Accuracy: 54.5847
#
# Time taken for the epoch 182.2059
# ----------------------------------------------------------------------------------------------------
# EPOCH 7
#
# Training ...
#
# Batch 1 Loss 0.5408
# Batch 100 Loss 0.4805
# Batch 200 Loss 0.5215
# Batch 300 Loss 0.5118
#
# Validating ...
#
# Train Loss: 0.5054 Train Accuracy: 83.6647 Validation Loss: 2.5868 Validation Accuracy: 56.3245
#
# Time taken for the epoch 182.4374
# ----------------------------------------------------------------------------------------------------
# EPOCH 8
#
# Training ...
#
# Batch 1 Loss 0.4621
# Batch 100 Loss 0.4628
# Batch 200 Loss 0.4592
# Batch 300 Loss 0.4375
#
# Validating ...
#
# Train Loss: 0.4431 Train Accuracy: 85.6041 Validation Loss: 2.3332 Validation Accuracy: 61.4323
#
# Time taken for the epoch 206.5566
# ----------------------------------------------------------------------------------------------------
# EPOCH 9
#
# Training ...
#
# Batch 1 Loss 0.3574
# Batch 100 Loss 0.4190
# Batch 200 Loss 0.3804
# Batch 300 Loss 0.3701
#
# Validating ...
#
# Train Loss: 0.3815 Train Accuracy: 87.5299 Validation Loss: 2.7114 Validation Accuracy: 58.4542
#
# Time taken for the epoch 182.0331
# ----------------------------------------------------------------------------------------------------
# EPOCH 10
#
# Training ...
#
# Batch 1 Loss 0.3804
# Batch 100 Loss 0.3580
# Batch 200 Loss 0.3388
# Batch 300 Loss 0.3372
#
# Validating ...
#
# Train Loss: 0.3358 Train Accuracy: 88.9181 Validation Loss: 2.3840 Validation Accuracy: 63.2050
#
# Time taken for the epoch 182.2113
# ----------------------------------------------------------------------------------------------------
# EPOCH 11
#
# Training ...
#
# Batch 1 Loss 0.3299
# Batch 100 Loss 0.3080
# Batch 200 Loss 0.3169
# Batch 300 Loss 0.3175
#
# Validating ...
#
# Train Loss: 0.2994 Train Accuracy: 90.1130 Validation Loss: 2.4430 Validation Accuracy: 63.5424
#
# Time taken for the epoch 181.8128
# ----------------------------------------------------------------------------------------------------
# EPOCH 12
#
# Training ...
#
# Batch 1 Loss 0.2779
# Batch 100 Loss 0.2741
# Batch 200 Loss 0.3207
# Batch 300 Loss 0.2711
#
# Validating ...
#
# Train Loss: 0.2688 Train Accuracy: 91.1769 Validation Loss: 2.1889 Validation Accuracy: 67.1188
#
# Time taken for the epoch 182.6900
# ----------------------------------------------------------------------------------------------------
# EPOCH 13
#
# Training ...
#
# Batch 1 Loss 0.2159
# Batch 100 Loss 0.2151
# Batch 200 Loss 0.2481
# Batch 300 Loss 0.2201
#
# Validating ...
#
# Train Loss: 0.2415 Train Accuracy: 92.0962 Validation Loss: 2.3027 Validation Accuracy: 66.7228
#
# Time taken for the epoch 182.7043
# ----------------------------------------------------------------------------------------------------
# EPOCH 14
#
# Training ...
#
# Batch 1 Loss 0.2264
# Batch 100 Loss 0.1884
# Batch 200 Loss 0.2209
# Batch 300 Loss 0.2186
#
# Validating ...
#
# Train Loss: 0.2216 Train Accuracy: 92.6845 Validation Loss: 2.2067 Validation Accuracy: 68.5577
#
# Time taken for the epoch 182.5348
# ----------------------------------------------------------------------------------------------------
# EPOCH 15
#
# Training ...
#
# Batch 1 Loss 0.2152
# Batch 100 Loss 0.1961
# Batch 200 Loss 0.2409
# Batch 300 Loss 0.2066
#
# Validating ...
#
# Train Loss: 0.2043 Train Accuracy: 93.3139 Validation Loss: 1.9674 Validation Accuracy: 71.7790
#
# Time taken for the epoch 184.6515
# ----------------------------------------------------------------------------------------------------
# EPOCH 16
#
# Training ...
#
# Batch 1 Loss 0.2171
# Batch 100 Loss 0.1830
# Batch 200 Loss 0.1750
# Batch 300 Loss 0.1500
#
# Validating ...
#
# Train Loss: 0.1895 Train Accuracy: 93.7428 Validation Loss: 2.0690 Validation Accuracy: 71.1822
#
# Time taken for the epoch 182.9875
# ----------------------------------------------------------------------------------------------------
# EPOCH 17
#
# Training ...
#
# Batch 1 Loss 0.1780
# Batch 100 Loss 0.1746
# Batch 200 Loss 0.1902
# Batch 300 Loss 0.1808
#
# Validating ...
#
# Train Loss: 0.1767 Train Accuracy: 94.2129 Validation Loss: 1.8785 Validation Accuracy: 74.4195
#
# Time taken for the epoch 182.7756
# ----------------------------------------------------------------------------------------------------
# EPOCH 18
#
# Training ...
#
# Batch 1 Loss 0.1816
# Batch 100 Loss 0.1529
# Batch 200 Loss 0.1394
# Batch 300 Loss 0.1855
#
# Validating ...
#
# Train Loss: 0.1666 Train Accuracy: 94.5480 Validation Loss: 1.9101 Validation Accuracy: 74.1294
#
# Time taken for the epoch 182.9713
# ----------------------------------------------------------------------------------------------------
# EPOCH 19
#
# Training ...
#
# Batch 1 Loss 0.1450
# Batch 100 Loss 0.1530
# Batch 200 Loss 0.1336
# Batch 300 Loss 0.1495
#
# Validating ...
#
# Train Loss: 0.1546 Train Accuracy: 95.0021 Validation Loss: 1.8614 Validation Accuracy: 74.9628
#
# Time taken for the epoch 182.9551
# ----------------------------------------------------------------------------------------------------
# EPOCH 20
#
# Training ...
#
# Batch 1 Loss 0.1585
# Batch 100 Loss 0.1257
# Batch 200 Loss 0.1351
# Batch 300 Loss 0.1270
#
# Validating ...
#
# Train Loss: 0.1466 Train Accuracy: 95.1886 Validation Loss: 1.6975 Validation Accuracy: 77.2371
#
# Time taken for the epoch 182.8968
# ----------------------------------------------------------------------------------------------------
#
# Model trained successfully !!
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train acc</td><td>▁▃▃▄▄▅▅▆▆▇▇▇▇▇██████</td></tr><tr><td>train loss</td><td>█▆▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>training time</td><td>█▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val acc</td><td>▁▂▃▃▃▄▄▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>val loss</td><td>█▇▆▇█▆▆▄▆▅▅▄▄▄▂▃▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train acc</td><td>95.18855</td></tr><tr><td>train loss</td><td>0.14661</td></tr><tr><td>training time</td><td>182.89684</td></tr><tr><td>val acc</td><td>77.23711</td></tr><tr><td>val loss</td><td>1.6975</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dry-sweep-8</strong>: <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/79tjvetz" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/runs/79tjvetz</a><br/>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220515_111446-79tjvetz/logs</code>
# wandb: Agent Starting Run: 8nezn39m with config:
# wandb: 	dropout: 0.3
# wandb: 	embedding_dim: 128
# wandb: 	enc_dec_layers: 2
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220515_121830-8nezn39m</code>
# Resuming run <strong><a href="https://wandb.ai/harshagudivada/cs6910-assignment3/runs/8nezn39m" target="_blank">toasty-sweep-9</a></strong> to <a href="https://wandb.ai/harshagudivada/cs6910-assignment3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof" target="_blank">https://wandb.ai/harshagudivada/cs6910-assignment3/sweeps/p25mgmof</a>
# ----------------------------------------------------------------------------------------------------
# EPOCH 1
#
# Training ...
# wandb: Ctrl + C detected. Stopping sweep.
